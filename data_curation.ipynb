# %% [markdown]
# ## DATA CURATION
# ---
#
# The goal of this section of the project is to gather more detailed information about the titles that exist in our dataset 'vgsales.csv'. This dataset contains more than 10,000 titles, but not much else in terms of descriptive features of the titles included. We will use the titles from this dataset as the basis for building a more robust one, which we will refer to from now on as the 'game library'.

# %%
# necessary libraries/modules
import os.path

import pandas as pd
import numpy as np
import requests
import json
import csv
from pathlib import Path
from importlib import reload
from os import listdir, getcwd, path
from typing import List, Any, Dict, Optional
from datetime import datetime, date
from itertools import islice
from datetime import timedelta
from ratelimit import limits, sleep_and_retry

# %%
# local py files
import data_pull
from data_pull import *
from api_auth_keys import *
reload(data_pull)
# Out:
# <module 'data_pull' from 'C:\\Users\\Matt\\DataspellProjects\\VGRecomendation\\data_pull.py'>

# %%
# data paths
datasets = Path(getcwd()).joinpath('datasets')
library = datasets.joinpath('library.csv')
new_data = datasets.joinpath('new_data.csv')
cleaned_library = datasets.joinpath('library_cleaned.csv')
original_dataset = datasets.joinpath('vgsales.csv')

game_library_data = pd.read_csv(library)
game_library = pd.DataFrame(game_library_data)

data = pd.read_csv(original_dataset)
df = pd.DataFrame(data)
df = df.drop_duplicates(subset=['Name'], keep='first')
df.shape[0]
# Out:
# 11493

# %% [markdown]
# ## Authorization Step
# ___

# %%
# 'twitch_client_id' and 'twitch_client_secret' are imported from 'api_auth_keys.py'
twitch_oauth2_link = f"https://id.twitch.tv/oauth2/token?client_id={twitch_client_id}&client_secret={twitch_client_secret}&grant_type=client_credentials"
base_igdb_url = "https://api.igdb.com/v4"
post = requests.post(url=twitch_oauth2_link)
post_json_dumped = json.loads(post.text)
access_token = post_json_dumped['access_token']
# expires_in = post_json_dumped['expires_in']
# token_type = post_json_dumped['token_type']

# %% [markdown]
# ### Game Titles / Chunking the data
# ---

# %%
game_titles = df['Name'].tolist()

cleaned_data = pd.read_csv(cleaned_library, encoding='utf-8')
clean_library = pd.DataFrame(cleaned_data)
clean_library[['id', 'name', 'genres', 'themes', 'summary']]
# Out:
#          id                                        name  \
# 0      2181                                  Wii Sports
# 1       358                           Super Mario Bros.
# 2      2183                              Mario Kart Wii
# 3      2182                           Wii Sports Resort
# 4      1076                       New Super Mario Bros.
# ...     ...                                         ...
# 3676   2028                                Elven Legacy
# 3677   1593                         Pillars of Eternity
# 3678   1840  Neverwinter Nights 2: Mask of the Betrayer
# 3679  78777                                    Legoland
# 3680  47482                                   Caladrius
#
#                             genres                        themes  \
# 0                 simulation,sport                         party
# 1             platformer,adventure                        action
# 2                           racing         action, comedy, party
# 3                            sport                         party
# 4             platformer,adventure                        action
# ...                            ...                           ...
# 3676              rpg,strategy,tbs                       fantasy
# 3677  rpg,strategy,adventure,indie                       fantasy
# 3678                  rpg,tactical                       fantasy
# 3679           simulation,strategy  action, sandbox, educational
# 3680                       shooter                        action
#
#                                                 summary
# 0     Bowl like a pro or go for that home run...\r\n...
# 1     A side scrolling 2D platformer and first entry...
# 2     Mario Kart Wii is a multiplayer-oriented racin...
# 3     Set off on a journey to a tropical island wher...
# 4     New Super Mario Bros. is a side-scrolling 2.5D...
# ...                                                 ...
# 3676  The shadows of destruction begin to loom on th...
# 3677  Prepare to be enchanted by a world where the c...
# 3678  Following the climactic battle against the Kin...
# 3679  Legoland is an educational game that shows how...
# 3680  Caladrius is an Action game, developed and pub...
#
# [3681 rows x 5 columns]

# %%
def chunk(it, size):
    it = iter(it)
    return iter(lambda: tuple(islice(it, size)), ())

# %%
# creates 115 chunks, each with 100 titles
chunks = list(chunk(game_titles, 100))
len(chunks)
# Out:
# 115

# %% [markdown]
# ### Creating a Data Pipeline
# ___
#
# The first hurdle we must cross is setting up a connection between our project and the data source. We must create a way to reliably request data and validate that what's returned is appropriate to include in our game library.
#
# IGDB's API has a rate limit of 4 requests/sec, so we must keep this in mind when establishing this connection as well.

# %%
FIELDS = ['id', 'release_dates', 'name', 'category', 'slug', 'platforms', 'genres', 'tags', 'age_ratings',
          'rating', 'rating_count', 'similar_games', 'themes', 'summary', 'involved_companies']

# %% [markdown]
#  #### Querying IGDB
# ---
#
# IGDB uses a SQL-like language called APICalypse to construct queries for requesting data. Currently, there are 3 different ways of searching for titles in the database which we will refer to as:
#     - `search`
#     - `name equals`
#     - `name like`
#
# These names do not refer to the actual syntax of the search query, but instead how the search is conducted.
#
# - `search` is the 'fuzziest' of the three, does not require titles to match exactly, but also returns less predictable results. `search` results are sorted by relevance descending, and hence, is incompatible with APICalypse's 'sort' keyword.
#     Ex: `f id,name,release_dates.y,category,slug,platforms.name,genres.name,tags,age_ratings.rating,rating,rating_count,similar_games.name,themes.name,summary,involved_companies.company.name;where (name = "The Legend of Zelda: Tears of the Kingdom") & (category = (0,1,2,8,9,10,11)) & (version_parent = null);limit 25;offset 0;`
#
# - `name equals` is best suited for titles that match exactly between our dataset and their respective entries in the database. Hence, its results are more limited, and more likely to return nothing.
#     Ex: `f id,name,release_dates.y,category,slug,platforms.name,genres.name,tags,age_ratings.rating,rating,rating_count,similar_games.name,themes.name,summary,involved_companies.company.name;where (name = "The Legend of Zelda: Tears of the Kingdom") & (category = (0,1,2,8,9,10,11)) & (version_parent = null);limit 25;offset 0;`
#
# - `name like` behaves a bit like both previous methods, and can be formatted to match on the beginning, end or entirety of a title.
#     Ex: `f id,name,release_dates.y,category,slug,platforms.name,genres.name,tags,age_ratings.rating,rating,rating_count,similar_games.name,themes.name,summary,involved_companies.company.name;where (name ~*"The Legend of Zelda: Tears of the Kingdom"*) & (category = (0,1,2,8,9,10,11)) & (version_parent = null);limit 25;offset 0;`

# %%
# test sample of a chunk:
# for c in chunks:
#     print(c)
chunks[15]
# Out:
# ('Dragon Ball Z: Taiketsu',
#  "Disney's Lilo & Stitch",
#  'Star Fox: Assault',
#  'Naruto: Ultimate Ninja Storm',
#  'NCAA Football 14',
#  'Doko Demo Issyo',
#  'Imagine: Fashion Designer New York',
#  'Bully: Scholarship Edition',
#  'Virtua Fighter',
#  'Championship Manager 99/00',
#  'Super Princess Peach',
#  'NHL 99',
#  'SoulCalibur III',
#  'F1 2012',
#  'World Tour Soccer',
#  'Disney Universe',
#  'Ridge Racer Revolution',
#  'Hot Wheels Turbo Racing',
#  'NCAA Football 99',
#  'Mortal Kombat: Armageddon',
#  'Aliens vs Predator',
#  'Freekstyle',
#  'Junior Brain Trainer',
#  'Darksiders',
#  'DiRT',
#  'Simple 1500 Series Vol. 1: The Mahjong',
#  'NBA Street V3',
#  'Sleeping Dogs',
#  'Mercenaries 2: World in Flames',
#  'Worms Armageddon',
#  'Hulk',
#  'NFL Quarterback Club 98',
#  'DJ Hero',
#  'Dora the Explorer: Dora Saves the Mermaids',
#  'Diablo II: Lord of Destruction',
#  'Naruto Shippuden: Ultimate Ninja Storm 4',
#  'Virtua Tennis 3',
#  'Seek and Destroy',
#  'Warhawk',
#  'Apollo Justice: Ace Attorney',
#  'Cosmic Ark',
#  'SOCOM: U.S. Navy SEALs Fireteam Bravo 2',
#  'Skylanders: Trap Team',
#  'Defender',
#  'Dance on Broadway',
#  'Adventure Island',
#  'Arc the Lad II',
#  'Tag Team Match M.U.S.C.L.E.',
#  'Derby Stallion 96',
#  'UFC Undisputed 3',
#  'NBA 2K3',
#  'Dragon Ball: XenoVerse',
#  'Dave Mirra Freestyle BMX',
#  'Imagine: Animal Doctor',
#  'Forza Motorsport',
#  'Monster Rancher 2',
#  'Pokemon Conquest',
#  'Guinness World Records: The Videogame',
#  'MVP Baseball 2003',
#  'Legacy of Kain: Soul Reaver',
#  'Disney Tangled',
#  'Tales of Destiny',
#  'ATV: Quad Power Racing',
#  'Disney Fairies: Tinker Bell and the Lost Treasure',
#  'Mega Man X4',
#  'Naruto: Clash of Ninja 2',
#  'Dance Dance Revolution SuperNOVA',
#  'Brink',
#  'F-Zero: Maximum Velocity',
#  'Bomberman 64',
#  'Jeremy McGrath Supercross 98',
#  'Project CARS',
#  'Kirby: Mass Attack',
#  'ZhuZhu Pets',
#  "Tom Clancy's Ghost Recon Advanced Warfighter 2",
#  'MotorStorm: Arctic Edge',
#  'WipEout Pure',
#  'EA Sports UFC',
#  'MX vs. ATV Unleashed',
#  'Tiger Woods PGA Tour 08',
#  'Rayman Origins',
#  'Epic Mickey 2: The Power of Two',
#  'NCAA March Madness 2004',
#  'Donkey Kong Land III',
#  'Bomberman',
#  'Street Fighter Alpha 3',
#  'Bulletstorm',
#  'Naruto: Clash of Ninja Revolution',
#  'ZombiU',
#  'Petz: Catz 2',
#  'Tales of Graces f',
#  'Final Fight 2',
#  'The Lost World: Jurassic Park',
#  'Ace Combat 6: Fires of Liberation',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Pong: The Next Level',
#  'Bayonetta 2',
#  'God of War: Ghost of Sparta',
#  'Ninja Gaiden II',
#  'Championship Manager 3')

# %%
passes, fails = [], []
# no release_dates
discards = []

# %%
# [[[[appended up to chunk 100]]]]
def request_chunks(start: int, stop: int, reset_passes: bool = True, display: bool = True, search_type: str = 'name equals'):
    """Automates post requests to IGDB for the slice of chunks specified"""
    # run collection process
    # reset passes with each run of this process, keep fails to retry later
    if reset_passes:
        passes = []
    for c in chunks[start:stop]:
        for i, j in enumerate(c):
            title = j
            search_type = search_type
            query = format_query(title, search_type=search_type)
            response = post_request(query, twitch_client_id, access_token)
            result = validate_response(response, title, exact_matches_only=True)
            # print(type(result))
            if isinstance(result, dict):
                # for some reason some of these don't have release_dates handling that here is easier
                if result.get('release_dates'):
                    if result.get('id') not in game_library.id.tolist():
                        if display:
                            print(f"PASS: {result.get('name')}")
                        parsed_response = parse_response(result)
                        passes.append(parsed_response)
                    else:
                        discards.append(result)
                elif not result.get('release_dates'):
                    discards.append(result)
            else:
                fails.append((title, search_type))
    if display:
        print(f"{len(passes)}, {len(fails)}, {len(discards)}")
    return passes, fails, discards

# %%
passes, fails, discards = request_chunks(101, len(chunks))
# Out:
# PASS: D1 Professional Drift Grand Prix Series
# PASS: Darius II
# PASS: RollerCoaster Tycoon 2: Triple Thrill Pack
# PASS: The Sims 2: Bon Voyage
# PASS: Divinity II: Flames of Vengeance
# PASS: Renegade Racers
# PASS: The King of Fighters: Maximum Impact - Maniax
# PASS: Wand of Fortune 2: Jikuu ni Shizumu Mokushiroku
# PASS: Combat Wings: The Great Battles of WWII
# PASS: Tank Beat
# PASS: Star Wars: Empire at War - Forces of Corruption
# PASS: Tube Slider
# PASS: Ghost Pirates of Vooju Island
# PASS: Pharaoh
# PASS: Pony Luv
# PASS: Vantage Master Portable
# PASS: Tropico 4: Modern Times
# PASS: Kensei: Sacred Fist
# PASS: Shanghai: True Valor
# PASS: Tokyo Xanadu eX+
# PASS: Vitamin Z Revolution
# PASS: Natalie Brooks: Mystery at Hillcrest High
# PASS: Treasure Chase
# PASS: RayCrisis: Series Termination
# PASS: Brandish: The Dark Revenant
# PASS: Samurai Shodown V
# PASS: Homeworld
# PASS: Invizimals: The Lost Kingdom
# PASS: Veggy World
# PASS: Doki Majo Plus
# PASS: Eureka Seven Vol. 2: The New Vision
# PASS: Motto! SoniComi
# PASS: Saint
# PASS: Steal Princess
# PASS: Legend: Hand of God
# PASS: Umineko no Naku Koro ni: Majo to Suiri no Rinbukyoku
# PASS: Dance! It's Your Stage
# PASS: Pebble Beach Golf Links
# PASS: The Lord of the Rings Online: Mines of Moria
# PASS: War Leaders: Clash of Nations
# PASS: Disney Sports Football
# PASS: Oil Rush
# PASS: Onechanbara Special
# PASS: Polar Bowler
# PASS: Chicago Enforcer
# PASS: Joker no Kuni no Alice: Wonderful Wonder World
# PASS: Cross Treasures
# PASS: Ruff Trigger: The Vanocore Conspiracy
# PASS: Silent Bomber
# PASS: TalkMan
# PASS: Elminage Gothic: Ulm Zakir to Yami no Gishiki
# PASS: Crayon Shin-Chan: Uchuu de Achoo!? Yuujou no Oba-Karate!!
# PASS: Invizimals: The Resistance
# PASS: Mushishi: Amefuru Sato
# PASS: Arcana Famiglia: Vascello Phantasma no Majutsushi
# PASS: ESPN MLS ExtraTime 2002
# PASS: Vitamin R
# PASS: Maximum Racing: Crash Car Racer
# PASS: Gakuen K: Wonderful School Days
# PASS: RollerCoaster Tycoon World
# PASS: Pastel Chime Continue
# PASS: Trapped Dead
# PASS: Super Fruit Fall
# PASS: Net High
# PASS: Kokoro Connect: Yochi Random
# PASS: Tenkai Knights: Brave Battle
# PASS: Mount & Blade: Warband
# PASS: Nervous Brickdown
# PASS: Legend of Kay Anniversary
# PASS: Spanish for Everyone!
# PASS: Battle Princess of Arcadias
# PASS: Angelique Retour
# PASS: Car Battler Joe
# PASS: Dino Dini's Kick Off Revival
# PASS: Atlantic Quest
# PASS: Tycoon City: New York
# PASS: Virtua Pro Football
# PASS: Adidas Power Soccer 98
# PASS: Natsuiro High School: Seishun Hakusho
# PASS: Kazoku Keikaku
# PASS: Rainbow Islands Revolution
# PASS: Virtual Kasparov
# PASS: Commandos 3: Destination Berlin
# PASS: Army Rescue
# PASS: Azada
# PASS: Zettai Meikyuu Grimm: Nanatsu no Kagi to Rakuen no Otome
# PASS: Hogs of War
# PASS: Point Blank 3
# PASS: Uru: Ages Beyond Myst
# PASS: Elvandia Story
# PASS: Puzzle Star Sweep
# PASS: Battle Spirits: Kiseki no Hasha
# PASS: X-Plane 10 Global
# PASS: The Cheetah Girls
# PASS: Rozen Maiden: Duellwalzer
# PASS: Winter Blast: 9 Snow & Ice Games
# PASS: The Talos Principle
# PASS: The Crow: City of Angels
# PASS: Broken Sword: The Sleeping Dragon
# PASS: Reversal Challenge
# PASS: Wild West Shootout
# PASS: Miyako
# PASS: Garfield's Nightmare
# PASS: Earth Seeker
# PASS: Barbie as the Princess and the Pauper
# PASS: Blood Bowl: Legendary Edition
# PASS: Pirates of the Burning Sea
# PASS: Mary King's Riding School 2
# PASS: Entaku no Seito: The Eternal Legend
# PASS: WorldShift
# PASS: 7 Roses: A Darkness Rises
# PASS: My Hero: Doctor
# PASS: Bomberman 2
# PASS: Peggle Nights
# PASS: Puzzle Guzzle
# PASS: Ketsui: Kizuna Jigoku Tachi Extra
# PASS: Aqua Panic!
# PASS: Kong: The Animated Series
# PASS: Agatha Christie: Death on the Nile
# PASS: Koisuru Otome to Shugo no Tate Portable
# PASS: Iridium Runners
# PASS: Tiny Toon Adventures: Wacky Stackers
# PASS: Emergency Mayhem
# PASS: Rising Zan: The Samurai Gunman
# PASS: Ultimate Puzzle Games
# PASS: Elminage II: Sousei no Megami to Unmei no Daichi
# PASS: Blazing Souls
# PASS: PDC World Championship Darts 2009
# PASS: Tail of the Sun
# PASS: Space Channel 5: Ulala's Cosmic Attack
# PASS: Airline Tycoon
# PASS: Virtua Quest
# PASS: Bejeweled Blitz
# PASS: Ozzy & Drix
# PASS: Barnyard Blast: Swine of the Night
# PASS: Castle Shikigami 2
# PASS: Pulse Racer
# PASS: Unreal Tournament 2004
# PASS: The Longest Journey
# PASS: Eyeshield 21: Portable Edition
# PASS: Stronghold Legends
# PASS: Winning Post 8 2016
# PASS: Golden Nugget Casino DS
# PASS: Machi-ing Maker 4
# PASS: Ketsui Death Label
# PASS: Prince of Stride
# PASS: SD Gundam Force
# PASS: Mechanic Master 2
# PASS: Cabbage Patch Kids: The Patch Puppy Rescue
# PASS: Pirates: Legend of the Black Buccaneer
# PASS: Post Mortem
# PASS: Amagoushi no Yakata
# PASS: Aedis Eclipse: Generation of Chaos
# PASS: Franklin: A Birthday Surprise
# PASS: Digimon Rumble Arena
# PASS: Vitamin X Evolution Plus
# PASS: Disciples III: Renaissance
# PASS: Nano Diver
# PASS: Elkrone no Atelier: Dear for Otomate
# PASS: DJ Star
# PASS: Top Gear RPM Tuning
# PASS: Cookie & Cream
# PASS: Memories Off: Yubikiri no Kioku
# PASS: Football Manager 2007
# PASS: Hurry Up Hedgehog!
# PASS: Hands On! Tangrams
# PASS: Discworld II: Mortality Bytes!
# PASS: One Piece Mansion
# PASS: Soul Eater: Monotone Princess
# PASS: Still Life 2
# PASS: Clock Zero: Shuuen no Ichibyou - ExTime
# PASS: Root Infinity Rexx
# PASS: Army Men: Major Malfunction
# PASS: Big Bass Fishing
# PASS: Reine des Fleurs
# PASS: Densha de Go! Shinkansen EX: Sanyou Shinkansen-hen
# PASS: Irritating Stick
# PASS: Kaleidoeve
# PASS: Simple 2000 Series Vol. 105: The Maid Fuku to Kikanjuu
# PASS: Pro Rally
# PASS: Kimi ni Todoke: Sodateru Omoi
# PASS: Zombie Hunters 2
# PASS: Custom Drive
# PASS: Ferrari: The Race Experience
# PASS: Achtung Panzer: Kharkov 1943
# PASS: Platypus
# PASS: Command & Conquer 4: Tiberian Twilight
# PASS: Farm Frenzy
# PASS: A Vampyre Story
# PASS: Phoenix Wright: Ace Attorney Trilogy
# PASS: LifeSigns: Surgical Unit
# PASS: I Love Horses: Rider's Paradise
# PASS: Zoey 101: Field Trip Fiasco
# PASS: Psychedelica of the Black Butterfly
# PASS: Assault Suit Leynos
# PASS: Elven Legacy
# PASS: Jet Impulse
# PASS: Shin Hisui no Shizuku: Hiiro no Kakera 2 Portable
# PASS: Pillars of Eternity
# PASS: Storm Lover Kai!!
# PASS: Race Driver: Create & Race
# PASS: Iron Soldier 3
# PASS: Storm Lover 2nd V
# PASS: Technic Beat
# PASS: Farming Simulator 2014
# PASS: Football Manager Live
# PASS: Black Cat
# PASS: Red Stone DS: Akaki Ishi ni Michibikareshi Monotachi
# PASS: Neverwinter Nights 2: Mask of the Betrayer
# PASS: Wand of Fortune Portable
# PASS: My Little Baby
# PASS: Super Robot Taisen XO
# PASS: Mortal Kombat: Tournament Edition
# PASS: Empire Deluxe
# PASS: Paranormal Pursuit: The Gifted One
# PASS: Hitotsu Tobashi Renai V
# PASS: Mystery Legends: Beauty and the Beast
# PASS: Jewel Quest II
# PASS: K-1 Grand Prix
# PASS: Legoland
# PASS: Caladrius
# PASS: Bunmei Kaika: Aoiza Ibunroku Saien
# PASS: Family Jockey
# PASS: Builder's Block
# PASS: Doraemon Wii: Himitsu Douguou Ketteisen!
# PASS: Death Connection Portable
# PASS: Duel Masters: Shadow of the Code
# PASS: Natsuzora no Monologue
# PASS: S.Y.K: Shinsetsu Saiyuuki Portable
# PASS: Grand Prix Legends
# PASS: Akatsuki no Amaneka to Aoi Kyojin
# PASS: Real Crimes: The Unicorn Killer
# PASS: Aladdin Magic Racer
# PASS: Agatha Christie: Peril at End House
# PASS: Dengeki Gakuen RPG: Cross of Venus Special
# PASS: DJ Max Technika Tune
# PASS: Crossroad Crisis
# PASS: Karnaaj Rally
# PASS: Dramatical Murder Re:code
# PASS: Scarlett: Nichijou no Kyoukaisen
# PASS: Mini Desktop Racing
# PASS: Neo Angelique Special
# PASS: Outdoors Unleashed: Africa 3D
# PASS: Planet Monsters
# PASS: Woody Woodpecker in Crazy Castle 5
# 245, 2668, 2627

# %%
len(passes), len(fails), len(discards)
# Out:
# (0, 0, 0)

# %%
# remove passed titles that already exist in our library
# dupes = 0
# passes_temp = passes.copy()
# for i, j in enumerate(passes_temp):
#     game_id = j.get('id')
#     if game_id in game_library.id.to_list():
#         dupes += 1
#         passes.remove(j)
# len(passes), dupes
# Out:
# (7, 59)

# %%
[k.get('name') for k in passes]
# Out:
# ['D1 Professional Drift Grand Prix Series',
#  'Darius II',
#  'RollerCoaster Tycoon 2: Triple Thrill Pack',
#  'The Sims 2: Bon Voyage',
#  'Divinity II: Flames of Vengeance',
#  'Renegade Racers',
#  'The King of Fighters: Maximum Impact - Maniax',
#  'Wand of Fortune 2: Jikuu ni Shizumu Mokushiroku',
#  'Combat Wings: The Great Battles of WWII',
#  'Tank Beat',
#  'Star Wars: Empire at War - Forces of Corruption',
#  'Tube Slider',
#  'Ghost Pirates of Vooju Island',
#  'Pharaoh',
#  'Pony Luv',
#  'Vantage Master Portable',
#  'Tropico 4: Modern Times',
#  'Kensei: Sacred Fist',
#  'Shanghai: True Valor',
#  'Tokyo Xanadu eX+',
#  'Vitamin Z Revolution',
#  'Natalie Brooks: Mystery at Hillcrest High',
#  'Treasure Chase',
#  'RayCrisis: Series Termination',
#  'Brandish: The Dark Revenant',
#  'Samurai Shodown V',
#  'Homeworld',
#  'Invizimals: The Lost Kingdom',
#  'Veggy World',
#  'Doki Majo Plus',
#  'Eureka Seven Vol. 2: The New Vision',
#  'Motto! SoniComi',
#  'Saint',
#  'Steal Princess',
#  'Legend: Hand of God',
#  'Umineko no Naku Koro ni: Majo to Suiri no Rinbukyoku',
#  "Dance! It's Your Stage",
#  'Pebble Beach Golf Links',
#  'The Lord of the Rings Online: Mines of Moria',
#  'War Leaders: Clash of Nations',
#  'Disney Sports Football',
#  'Oil Rush',
#  'Onechanbara Special',
#  'Polar Bowler',
#  'Chicago Enforcer',
#  'Joker no Kuni no Alice: Wonderful Wonder World',
#  'Cross Treasures',
#  'Ruff Trigger: The Vanocore Conspiracy',
#  'Silent Bomber',
#  'TalkMan',
#  'Elminage Gothic: Ulm Zakir to Yami no Gishiki',
#  'Crayon Shin-Chan: Uchuu de Achoo!? Yuujou no Oba-Karate!!',
#  'Invizimals: The Resistance',
#  'Mushishi: Amefuru Sato',
#  'Arcana Famiglia: Vascello Phantasma no Majutsushi',
#  'ESPN MLS ExtraTime 2002',
#  'Vitamin R',
#  'Maximum Racing: Crash Car Racer',
#  'Gakuen K: Wonderful School Days',
#  'RollerCoaster Tycoon World',
#  'Pastel Chime Continue',
#  'Trapped Dead',
#  'Super Fruit Fall',
#  'Net High',
#  'Kokoro Connect: Yochi Random',
#  'Tenkai Knights: Brave Battle',
#  'Mount & Blade: Warband',
#  'Nervous Brickdown',
#  'Legend of Kay Anniversary',
#  'Spanish for Everyone!',
#  'Battle Princess of Arcadias',
#  'Angelique Retour',
#  'Car Battler Joe',
#  "Dino Dini's Kick Off Revival",
#  'Atlantic Quest',
#  'Tycoon City: New York',
#  'Virtua Pro Football',
#  'Adidas Power Soccer 98',
#  'Natsuiro High School: Seishun Hakusho',
#  'Kazoku Keikaku',
#  'Rainbow Islands Revolution',
#  'Virtual Kasparov',
#  'Commandos 3: Destination Berlin',
#  'Army Rescue',
#  'Azada',
#  'Zettai Meikyuu Grimm: Nanatsu no Kagi to Rakuen no Otome',
#  'Hogs of War',
#  'Point Blank 3',
#  'Uru: Ages Beyond Myst',
#  'Elvandia Story',
#  'Puzzle Star Sweep',
#  'Battle Spirits: Kiseki no Hasha',
#  'X-Plane 10 Global',
#  'The Cheetah Girls',
#  'Rozen Maiden: Duellwalzer',
#  'Winter Blast: 9 Snow & Ice Games',
#  'The Talos Principle',
#  'The Crow: City of Angels',
#  'Broken Sword: The Sleeping Dragon',
#  'Reversal Challenge',
#  'Wild West Shootout',
#  'Miyako',
#  "Garfield's Nightmare",
#  'Earth Seeker',
#  'Barbie as the Princess and the Pauper',
#  'Blood Bowl: Legendary Edition',
#  'Pirates of the Burning Sea',
#  "Mary King's Riding School 2",
#  'Entaku no Seito: The Eternal Legend',
#  'WorldShift',
#  '7 Roses: A Darkness Rises',
#  'My Hero: Doctor',
#  'Bomberman 2',
#  'Peggle Nights',
#  'Puzzle Guzzle',
#  'Ketsui: Kizuna Jigoku Tachi Extra',
#  'Aqua Panic!',
#  'Kong: The Animated Series',
#  'Agatha Christie: Death on the Nile',
#  'Koisuru Otome to Shugo no Tate Portable',
#  'Iridium Runners',
#  'Tiny Toon Adventures: Wacky Stackers',
#  'Emergency Mayhem',
#  'Rising Zan: The Samurai Gunman',
#  'Ultimate Puzzle Games',
#  'Elminage II: Sousei no Megami to Unmei no Daichi',
#  'Blazing Souls',
#  'PDC World Championship Darts 2009',
#  'Tail of the Sun',
#  "Space Channel 5: Ulala's Cosmic Attack",
#  'Airline Tycoon',
#  'Virtua Quest',
#  'Bejeweled Blitz',
#  'Ozzy & Drix',
#  'Barnyard Blast: Swine of the Night',
#  'Castle Shikigami 2',
#  'Pulse Racer',
#  'Unreal Tournament 2004',
#  'The Longest Journey',
#  'Eyeshield 21: Portable Edition',
#  'Stronghold Legends',
#  'Winning Post 8 2016',
#  'Golden Nugget Casino DS',
#  'Machi-ing Maker 4',
#  'Ketsui Death Label',
#  'Prince of Stride',
#  'SD Gundam Force',
#  'Mechanic Master 2',
#  'Cabbage Patch Kids: The Patch Puppy Rescue',
#  'Pirates: Legend of the Black Buccaneer',
#  'Post Mortem',
#  'Amagoushi no Yakata',
#  'Aedis Eclipse: Generation of Chaos',
#  'Franklin: A Birthday Surprise',
#  'Digimon Rumble Arena',
#  'Vitamin X Evolution Plus',
#  'Disciples III: Renaissance',
#  'Nano Diver',
#  'Elkrone no Atelier: Dear for Otomate',
#  'DJ Star',
#  'Top Gear RPM Tuning',
#  'Cookie & Cream',
#  'Memories Off: Yubikiri no Kioku',
#  'Football Manager 2007',
#  'Hurry Up Hedgehog!',
#  'Hands On! Tangrams',
#  'Discworld II: Mortality Bytes!',
#  'One Piece Mansion',
#  'Soul Eater: Monotone Princess',
#  'Still Life 2',
#  'Clock Zero: Shuuen no Ichibyou - ExTime',
#  'Root Infinity Rexx',
#  'Army Men: Major Malfunction',
#  'Big Bass Fishing',
#  'Reine des Fleurs',
#  'Densha de Go! Shinkansen EX: Sanyou Shinkansen-hen',
#  'Irritating Stick',
#  'Kaleidoeve',
#  'Simple 2000 Series Vol. 105: The Maid Fuku to Kikanjuu',
#  'Pro Rally',
#  'Kimi ni Todoke: Sodateru Omoi',
#  'Zombie Hunters 2',
#  'Custom Drive',
#  'Ferrari: The Race Experience',
#  'Achtung Panzer: Kharkov 1943',
#  'Platypus',
#  'Command & Conquer 4: Tiberian Twilight',
#  'Farm Frenzy',
#  'A Vampyre Story',
#  'Phoenix Wright: Ace Attorney Trilogy',
#  'LifeSigns: Surgical Unit',
#  "I Love Horses: Rider's Paradise",
#  'Zoey 101: Field Trip Fiasco',
#  'Psychedelica of the Black Butterfly',
#  'Assault Suit Leynos',
#  'Elven Legacy',
#  'Jet Impulse',
#  'Shin Hisui no Shizuku: Hiiro no Kakera 2 Portable',
#  'Pillars of Eternity',
#  'Storm Lover Kai!!',
#  'Race Driver: Create & Race',
#  'Iron Soldier 3',
#  'Storm Lover 2nd V',
#  'Technic Beat',
#  'Farming Simulator 2014',
#  'Football Manager Live',
#  'Black Cat',
#  'Red Stone DS: Akaki Ishi ni Michibikareshi Monotachi',
#  'Neverwinter Nights 2: Mask of the Betrayer',
#  'Wand of Fortune Portable',
#  'My Little Baby',
#  'Super Robot Taisen XO',
#  'Mortal Kombat: Tournament Edition',
#  'Empire Deluxe',
#  'Paranormal Pursuit: The Gifted One',
#  'Hitotsu Tobashi Renai V',
#  'Mystery Legends: Beauty and the Beast',
#  'Jewel Quest II',
#  'K-1 Grand Prix',
#  'Legoland',
#  'Caladrius',
#  'Bunmei Kaika: Aoiza Ibunroku Saien',
#  'Family Jockey',
#  "Builder's Block",
#  'Doraemon Wii: Himitsu Douguou Ketteisen!',
#  'Death Connection Portable',
#  'Duel Masters: Shadow of the Code',
#  'Natsuzora no Monologue',
#  'S.Y.K: Shinsetsu Saiyuuki Portable',
#  'Grand Prix Legends',
#  'Akatsuki no Amaneka to Aoi Kyojin',
#  'Real Crimes: The Unicorn Killer',
#  'Aladdin Magic Racer',
#  'Agatha Christie: Peril at End House',
#  'Dengeki Gakuen RPG: Cross of Venus Special',
#  'DJ Max Technika Tune',
#  'Crossroad Crisis',
#  'Karnaaj Rally',
#  'Dramatical Murder Re:code',
#  'Scarlett: Nichijou no Kyoukaisen',
#  'Mini Desktop Racing',
#  'Neo Angelique Special',
#  'Outdoors Unleashed: Africa 3D',
#  'Planet Monsters',
#  'Woody Woodpecker in Crazy Castle 5']

# %%
[k.get('name') for k in discards]
# Out:
# ['SingStar: Back to the 80s',
#  "Crash 'N' Burn",
#  "Final Fantasy Fables: Chocobo's Dungeon",
#  'Disaster Report',
#  'We Sing Robbie Williams',
#  "Akiba's Trip: Undead & Undressed",
#  'College Hoops 2K7',
#  'Baja: Edge of Control',
#  'Wild Wild Racing',
#  "The Bard's Tale",
#  'Conflict Zone',
#  'de Blob 2',
#  '50 Cent: Blood on the Sand',
#  'Tenchu: Return From Darkness',
#  'Neo Contra',
#  'MVP Baseball',
#  'Breakaway IV',
#  "Now! That's What I Call Music: Dance & Sing",
#  "Yu-Gi-Oh! 5D's World Championship 2011: Over the Nexus",
#  'Senran Kagura 2: Deep Crimson',
#  'Champion Jockey: G1 Jockey & Gallop Racer',
#  'HBO Boxing',
#  'Yoga Wii',
#  "Cabela's Survival: Shadows of Katmai",
#  'Prince of Persia: Revelations',
#  'Front Mission 5: Scars of the War',
#  'Wedding Dash',
#  'Hot Shots Tennis: Get a Grip',
#  'Summoner 2',
#  'The Land Before Time: Big Water Adventure',
#  'Shadow of Destiny',
#  'ClayFighter 63 1/3',
#  'Heroes of Ruin',
#  'Bastard!! Utsuro Naru Kamigami no Utsuwa',
#  'Angel Blade: Neo Tokyo Guardians',
#  'Threads of Fate',
#  'PoPoLoCrois Monogatari II',
#  'Vampire Rain',
#  'Deus Ex: The Conspiracy',
#  'Unreal II: The Awakening',
#  'Rumble Racing',
#  'Disgaea D2: A Brighter Darkness',
#  'Just Dance: Greatest Hits',
#  "Shrek: Reekin' Havoc",
#  'Solatorobo: Red the Hunter',
#  'Rollcage',
#  'Project: Snowblind',
#  "Tony Hawk's Motion",
#  'Super Robot Taisen K',
#  'Mortal Kombat: Special Forces',
#  'Dragon Ball Z: Harukanaru Densetsu',
#  'Greg Hastings Paintball 2',
#  'Evil Dead: Regeneration',
#  'Marvel Super Hero Squad: Comic Combat',
#  'X-Men: Children of the Atom',
#  'Tiger Woods PGA Tour',
#  'Yarudora Series Vol. 2: Kisetsu wo Dakishimete',
#  'NHL 2K3',
#  'The Naked Brothers Band: The Video Game',
#  'Final Fight One',
#  'Anarchy Reigns',
#  'J-League Pro Soccer Club o Tsukurou! 7 Euro Plus',
#  'Bugs Bunny & Taz: Time Busters',
#  'Kung Fu Rider',
#  'Power Rangers: Wild Force',
#  'The Wolf Among Us',
#  'Battle of Giants: Dinosaurs Strike',
#  'Discovery Kids: Pony Paradise',
#  'Mary-Kate and Ashley: Girls Night Out',
#  "Cabela's North American Adventures",
#  'Enchanted Arms',
#  'Trade & Battle: Card Hero',
#  'World Championship Cards',
#  'Chronicles of Mystery: Curse of the Ancient Temple',
#  'Capcom Fighting Evolution',
#  'Frogger 3D',
#  'Buzz! The Schools Quiz',
#  'Suikoden Tactics',
#  'Mobile Suit Gundam: Crossfire',
#  'Phantasy Star Online',
#  'Crazy Taxi 3: High Roller',
#  'Shining Blade',
#  'Fairy Fencer F',
#  'Atelier Shallie: Alchemists of the Dusk Sea',
#  'The Ultimate Red Ball Challenge',
#  'Arcana Heart 3',
#  'Tekken 3D: Prime Edition',
#  'Deal or No Deal: The Banker is Back!',
#  "Jillian Michaels' Fitness Adventure",
#  'Saturday Night Speedway',
#  'Langrisser III',
#  'Dragon Ball: Revenge of King Piccolo',
#  'Spectrobes: Origins',
#  'Earth Defense Force: Insect Armageddon',
#  'Pitfall: The Lost Expedition',
#  'XCOM 2',
#  'International Cricket 2010',
#  'ESPN MLB Baseball',
#  'Neighborhood Games',
#  'All Star Pro-Wrestling',
#  'Way of the Samurai 4',
#  'Harvest Moon: More Friends of Mineral Town',
#  'NHL 17',
#  'Camping Mama: Outdoor Adventures',
#  '7th Dragon 2020',
#  'Imagine: Babyz Fashion',
#  'Dead to Rights II',
#  'Super Dodge Ball Advance',
#  'Ridge Racer 6',
#  'Treasure World',
#  'Body and Brain Connection',
#  'MDK',
#  "No More Heroes: Heroes' Paradise",
#  'NCAA Final Four 2004',
#  'Twisted Edge Extreme Snowboarding',
#  'Body Harvest',
#  'Super Robot Taisen 64',
#  'IHRA Drag Racing 2004',
#  'Shining Hearts',
#  'Code of Princess',
#  'The Con',
#  "Tony Hawk's Pro Skater 5",
#  'The Witch and the Hundred Knight',
#  'Nobunaga no Yabou: Reppuuden',
#  'Schlag den Raab',
#  'Treasure Hunter G',
#  'Untold Legends: Dark Kingdom',
#  'The Cheetah Girls: Passport to Stardom',
#  'My Secret World by Imagine',
#  'Soldier of Fortune: Payback',
#  'Bleach: The 3rd Phantom',
#  'Gladius',
#  'Family Feud: 2012 Edition',
#  'Spore Hero Arena',
#  'Record of Agarest War',
#  'Taiko no Tatsujin: Go! Go! Godaime',
#  'Taiko Drum Master',
#  "Tom Clancy's Splinter Cell: Essentials",
#  'Forgotten Realms: Demon Stone',
#  'Looney Tunes: Space Race',
#  'NASCAR Unleashed',
#  'Playboy: The Mansion',
#  'Shiren the Wanderer',
#  'Ore no Shikabane o Koete Yuke',
#  'Shaman King: Spirit of Shamans',
#  'MC Groovz Dance Craze',
#  'Tom and Jerry in House Trap',
#  'UFC: Tapout',
#  'Aikatsu! Cinderella Lesson',
#  'Predator: Concrete Jungle',
#  'Beyblade: Metal Fusion - Battle Fortress',
#  'Demon Gaze',
#  'Zombie Army Trilogy',
#  'Mana Khemia 2: Fall of Alchemy',
#  'Iron Chef America: Supreme Cuisine',
#  'The King of Fighters XI',
#  'Bound By Flame',
#  'Conflict: Denied Ops',
#  'Saw II: Flesh & Blood',
#  'Sniper Elite',
#  'Arc Rise Fantasia',
#  'Kouchuu Ouja Mushi King: Greatest Champion e no Michi DS',
#  'Parlor! Mini 4',
#  'The Spiderwick Chronicles',
#  'Dinotopia: The Timestone Pirates',
#  'Quantum Theory',
#  'NCAA Final Four 2003',
#  'Air Conflicts: Secret Wars',
#  'Dream Salon',
#  'Disgaea DS',
#  'Space Invaders Extreme 2',
#  'Hidden Mysteries: Vampire Secrets',
#  'Breath of Fire: Dragon Quarter',
#  'Super Robot Taisen: Scramble Commander',
#  'Re-Volt',
#  'Conception II: Children of the Seven Stars',
#  'DanceMasters',
#  "Disney's Magical Mirror Starring Mickey Mouse",
#  'Jeep Thrills',
#  'FaceBreaker',
#  'Might & Magic: Clash of Heroes',
#  'IHRA Professional Drag Racing 2005',
#  'Mace Griffin: Bounty Hunter',
#  'Tales of the World: Narikiri Dungeon 2',
#  'Silent Scope 2: Dark Silhouette',
#  'NHL Hitz Pro',
#  'Allied General',
#  'Kamen Rider: Battride War',
#  'Armored Core: For Answer',
#  'uDraw Studio: Instant Artist',
#  'Naruto: Ninja Destiny',
#  'Darkstalkers 3',
#  "SpongeBob's Surf & Skate Roadtrip",
#  'Death Jr.',
#  'Inazuma Eleven Strikers 2012 Xtreme',
#  'SpongeBob SquigglePants 3D',
#  'Monster 4x4: Stunt Racer',
#  "Frogger's Adventures 2: The Lost Wand",
#  'Sudeki',
#  'Mace: The Dark Age',
#  'AeroFighters Assault',
#  'Squeeballs Party',
#  'Family Game Night 4: The Game Show',
#  'Fighter Within',
#  'Warhammer: Shadow of the Horned Rat',
#  'Warriors: Legends of Troy',
#  'ESPN International Track & Field',
#  'Lunar Legend',
#  'Conflict: Global Terror',
#  'Valhalla Knights 3',
#  'Gungrave',
#  'Phantasy Star Universe',
#  'God Eater Resurrection',
#  'Tenchu: Fatal Shadows',
#  'Active Health with Carol Vorderman',
#  'Jewel Master: Cradle of Athena',
#  'Big Air',
#  'Shining Force II',
#  'Arcania: Gothic 4',
#  'Mushroom Men: The Spore Wars',
#  'Zumba Fitness Rush',
#  'Daigasso! Band Brothers',
#  'Thoroughbred Breeder',
#  'Momotarou Dentetsu World',
#  'Doctor Who: Return to Earth',
#  'The Munchables',
#  'We Dance',
#  'Mathews Bowhunting',
#  'One Piece: Unlimited Adventure',
#  'Remington Super Slam Hunting: North America',
#  'Penguin no Mondai X: Tenkuu no 7 Senshi',
#  'The Scorpion King: Sword of Osiris',
#  'Bubsy 3D',
#  'Reel Fishing Paradise 3D',
#  'NCAA Final Four 2001',
#  'Farmtopia',
#  'Robin Hood: Defender of the Crown',
#  'SD Gundam GX',
#  'R-Type Final',
#  'Jackie Chan Adventures: Legend of the Dark Hand',
#  'Sega GT 2002',
#  'Jurassic: The Hunted',
#  'J-League Pro Soccer Club o Tsukurou! 5',
#  'Hot Wheels: Battle Force 5',
#  'Dragon Blade: Wrath of Fire',
#  'Phantasy Star Nova',
#  'Samurai Warriors: State of War',
#  'Call of Juarez',
#  'The Bee Game',
#  'EverQuest Online Adventures: Frontiers',
#  'NBA Ballers: Chosen One',
#  'Phantasy Star Online Ver. 2',
#  'EyePet & Friends',
#  'Fight Club',
#  'Dance Dance Revolution: Disney Grooves',
#  'Harvest Moon: A Wonderful Life Special Edition',
#  'Sports Illustrated for Kids: Football',
#  'Close Combat: First to Fight',
#  'MotoGP 14',
#  "Indiana Jones and the Emperor's Tomb",
#  'Buffy the Vampire Slayer: Chaos Bleeds',
#  'Half-Minute Hero',
#  'Reel Fishing II',
#  'Ringling Bros. and Barnum & Bailey Circus',
#  'Driving Emotion Type-S',
#  'Siren',
#  'Naruto Shippuden: Dragon Blade Chronicles',
#  'Super Robot Taisen J',
#  'Lips: Party Classics',
#  'Casper: Friends Around the World',
#  'Jurassic Park III: Island Attack',
#  'Shape Up',
#  'AirForce Delta Storm',
#  'Fear Effect 2: Retro Helix',
#  'Klonoa: Door to Phantomile',
#  'Hatsune Miku and Future Stars: Project Mirai',
#  "Cabela's Adventure Camp",
#  'Bloody Roar: Primal Fury',
#  'We Sing UK Hits',
#  'Trinity Universe',
#  'Super Robot Taisen UX',
#  'Test Drive Off-Road Wide Open',
#  'Guilty Gear Xrd: Sign',
#  'Battle Commander: Hachibushu Shura no Heihou',
#  'Odin Sphere: Leifthrasir',
#  'Mega Man X: Command Mission',
#  'Ridge Racer Unbounded',
#  'The Adventures of Cookie & Cream',
#  'MindJack',
#  'Daigasso! Band Brothers P',
#  'World of Outlaws: Sprint Cars',
#  'Shadow Madness',
#  'Aliens: Infestation',
#  'The Game of Life / Yahtzee / Payday',
#  'American Chopper 2: Full Throttle',
#  'Heavy Fire: Afghanistan',
#  'Commandos 2: Men of Courage',
#  "Chuck E. Cheese's Party Games",
#  'Mercury Meltdown Revolution',
#  'Brunswick Circuit Pro Bowling',
#  'Velvet Assassin',
#  'Ball Breakers',
#  'Armored Core: Last Raven',
#  'Super Robot Taisen A Portable',
#  'Tales of the Tempest',
#  'UFC: Sudden Impact',
#  'Shawn Johnson Gymnastics',
#  'NBA Hoopz',
#  'Nancy Drew: The Hidden Staircase',
#  'Speedball 2100',
#  'Fancy Nancy: Tea Party Time!',
#  'Summon Night 4',
#  'My French Coach',
#  'Camp Rock: The Final Jam',
#  'NBA Starting Five',
#  'Castlevania Judgment',
#  'Dead or Alive Paradise',
#  'The Suffering: Ties That Bind',
#  'EyeToy: Kinetic',
#  'Stormrise',
#  'MotoGP 10/11',
#  'Hyperdimension Neptunia U: Action Unleashed',
#  'Sports Illustrated for Kids: Baseball',
#  'Fairytale Fights',
#  'Warriors of Might and Magic',
#  'Back to the Future: The Game',
#  'Project Spark',
#  'Backyard Sports Football: Rookie Rush',
#  'Lost in Blue 3',
#  'Rapala Fishing Frenzy 2009',
#  'SaGa 2: Hihou Densetsu - Goddess of Destiny',
#  'Smash Court Tennis Pro Tournament',
#  'The Cursed Crusade',
#  'Super Robot Taisen L',
#  'NBA Inside Drive 2004',
#  "The King of Fighters '97",
#  "Cabela's Big Game Hunter: Hunting Party",
#  'Time Commando',
#  "Professional Fisherman's Tour: Northern Hemisphere",
#  'Kekkaishi: Karasumori Ayakashi Kidan',
#  'Gretzky NHL 2005',
#  'The Secret World',
#  'NHL 2K9',
#  'PlayStation Move Heroes',
#  'ESPN Final Round Golf 2002',
#  'Sudoku Gridmaster',
#  'Sound Novel Evolution 1: Otogirisou Sosei-Hen',
#  'Dementium: The Ward',
#  'Goblin Commander: Unleash the Horde',
#  'Hello Kitty: Happy Party Pals',
#  'Finding Nemo: Escape to the Big Blue',
#  "Backyard Baseball '10",
#  'RoadKill',
#  'Macross Ultimate Frontier',
#  'Jillian Michaels Fitness Ultimatum 2011',
#  'Pursuit Force: Extreme Justice',
#  'Tokyo Xtreme Racer',
#  "Professor Heinz Wolff's Gravity",
#  'Thief: Deadly Shadows',
#  'Buzz! Brain of the UK',
#  'NBA 09: The Inside',
#  'Transformers: Prime',
#  'Luxor 3',
#  'Bratz Kidz',
#  'Mahjong Fight Club',
#  'World Driver Championship',
#  'Bomberman 64: The Second Attack!',
#  'Zoo Hospital',
#  'Time and Eternity',
#  'Gundam Assault Survive',
#  "Disney's Home on the Range",
#  "Sid Meier's Civilization IV",
#  'Space Griffon VF-9',
#  'NBA Live 16',
#  'Solitaire Overload Plus',
#  'Gyakuten Saiban 3',
#  'Tak: Mojo Mistake',
#  'Gallop Racer 2001',
#  'Nightmare Creatures II',
#  'Marble Saga: Kororinpa',
#  'Fuzion Frenzy 2',
#  'Bomberman B-Daman',
#  'Terminator 3: The Redemption',
#  'Beat Down: Fists of Vengeance',
#  'MotoGP 15',
#  'Naruto Shippuden: Ultimate Ninja 5',
#  'Shrek Extra Large',
#  'World Tour Soccer 2006',
#  'Gunvalkyrie',
#  "VR Golf '97",
#  'Michael Jackson: The Experience 3D',
#  'Digimon Story: Cyber Sleuth',
#  'Off-World Interceptor Extreme',
#  'Disney Golf',
#  'Custom Robo Arena',
#  'Clock Tower II: The Struggle Within',
#  'Mega Man Network Transmission',
#  'Naval Assault: The Killing Tide',
#  'Hellboy: The Science of Evil',
#  'Lost Kingdoms',
#  'WRC 2: FIA World Rally Championship',
#  'Learning to Spell',
#  'Super Power League',
#  'Easy Piano',
#  'Sega Superstars',
#  'Klonoa',
#  'Spyro: Shadow Legacy',
#  'Itoi Shigesato no Bass Tsuri No. 1',
#  'Cubivore: Survival of the Fittest',
#  "Mr. Do!'s Castle",
#  'Phantasy Star Online 2',
#  'PoPoLoCrois: Hajimari no Bouken',
#  'Star Wars: Super Bombad Racing',
#  'Hamster Heroes',
#  'Leisure Suit Larry: Box Office Bust',
#  'Alien Resurrection',
#  'World Tour Soccer 2005',
#  'Dungeon Siege: Throne of Agony',
#  'Spider-Man: Web of Shadows - Amazing Allies Edition',
#  'Lufia: Curse of the Sinistrals',
#  'ESPN College Hoops',
#  'Guilty Gear Judgment',
#  'Pen 1 Grand Prix: Penguin no Mondai Special',
#  'Kya: Dark Lineage',
#  'Medieval Games',
#  'Stronghold 3',
#  'Kid Adventures: Sky Captain',
#  'Lethal Skies II',
#  'Doctor Lautrec and the Forgotten Knights',
#  'World Stadium 4',
#  'Magic: The Gathering - Battlegrounds',
#  'Bladestorm: Nightmare',
#  'Otogirisou',
#  'SD Gundam G Generation 3D',
#  'Grease Dance',
#  'My Baby 3 & Friends',
#  "NASCAR '14",
#  'Puzzle Quest: Galactrix',
#  'DS Rakubiki Jiten',
#  'Fatal Frame II: Crimson Butterfly',
#  'Shadow Man: 2econd Coming',
#  "Yu-Gi-Oh! 5D's Tag Force 6",
#  'Eragon',
#  'Scarface: Money. Power. Respect.',
#  'Silent Scope 3',
#  'International Superstar Soccer Deluxe',
#  'Intellivision Lives!',
#  'Field Commander',
#  'Little League World Series Baseball 2009',
#  'The King of Fighters XII',
#  'Doctor Who: Evacuation Earth',
#  'The Wild Thornberrys: Chimp Chase',
#  'Fighters Destiny',
#  'Asteroids Hyper 64',
#  'Tom and Jerry in Fists of Furry',
#  'Destruction Derby 64',
#  'Buck Bumble',
#  'California Speed',
#  'Dragon Ball: Origins 2',
#  'Innocent Life: A Futuristic Harvest Moon',
#  'Macross Ace Frontier',
#  'Black & Bruised',
#  'Scripps Spelling Bee',
#  'Ener-G Horse Riders',
#  'Time Hollow',
#  "SpongeBob's Truth or Square",
#  'Battle Soccer: Field no Hasha',
#  'Amped 3',
#  'Family Party: 30 Great Games Outdoor Fun',
#  'FlatOut 2',
#  'Naruto: Ultimate Ninja Heroes 2 - The Phantom Fortress',
#  'Burger Island',
#  'Just Dance: Disney Party',
#  'Chessmaster: The Art of Learning',
#  'Konami Krazy Racers',
#  'Saturday Night Slam Masters',
#  'Blitz: The League II',
#  'F-Zero: GP Legend',
#  'Racing Lagoon',
#  'Mr. Driller 2',
#  'Trivial Pursuit: Bet You Know It',
#  'Mugen Souls',
#  'Yakuza Kiwami',
#  'Psychic Force',
#  'Trigger Man',
#  'The Godfather: Blackhand Edition',
#  'Backyard Sports: Sandlot Sluggers',
#  'Arcade Zone',
#  '7th Dragon III Code: VFD',
#  'Bust-A-Move Bash!',
#  'Toriko: Gourmet Monsters!',
#  'White Knight Chronicles: Origins',
#  'Return to PopoloCrois: A Story of Seasons Fairytale',
#  'History Civil War: Secret Missions',
#  'Derby Stallion 64',
#  'Dark Rift',
#  'Tokyo Xanadu',
#  "Candace Kane's Candy Factory",
#  'Rock Band: Metal Track Pack',
#  'Winning Post 4',
#  'DreamWorks Super Star Kartz',
#  'Geist',
#  'Cardinal Syn',
#  'Mobile Suit Gundam Side Story III: Sabakareshi Mono',
#  'Nancy Drew: The White Wolf of Icicle Creek',
#  'Battle Stadium D.O.N',
#  "Rubik's World",
#  'Gallop & Ride!',
#  'Fugitive Hunter: War on Terror',
#  'Ore no Imouto ga Konna ni Kawaii wake ga Nai Portable',
#  'Baseball Blast!',
#  'Harvest Moon: Hero of Leaf Valley',
#  'Darkstalkers Chronicle: The Chaos Tower',
#  'Toy Story Racer',
#  'Galerians',
#  'DrumMania',
#  'Tamagotchi no Narikiri Channel',
#  'Medal of Honor: Infiltrator',
#  'Blazing Dragons',
#  'Geometry Wars: Galaxies',
#  'High Velocity Bowling',
#  'Tamagotchi Collection',
#  'Pac-Man Party 3D',
#  'Mad Dash Racing',
#  'Dreamworks 2-in-1 Party Pack',
#  'Summon Night 5',
#  'BMX XXX',
#  'Guilty Gear X2 #Reload',
#  'Moshi Monsters: Katsuma Unleashed',
#  'Elf: The Movie',
#  'Metal Slug 7',
#  'Grabbed by the Ghoulies',
#  'Ys: The Oath in Felghana',
#  'Mega Man Powered Up',
#  'CSI: 3 Dimensions of Murder',
#  'Deception IV: Blood Ties',
#  'Pipe Dreams 3D',
#  "Adventure Time: Explore the Dungeon Because I Don't Know!",
#  'Lost Dimension',
#  "Fox Sports Golf '99",
#  'Fatal Frame',
#  'The Fifth Element',
#  'Fast Food Panic',
#  'Diner Dash: Flo on the Go',
#  'Adrenalin Misfits',
#  'Okaeri! Chibi-Robo! Happy Richie Oosouji',
#  'Casper: Spirit Dimensions',
#  'Thunder Truck Rally',
#  'Klonoa: Empire of Dreams',
#  'Second Sight',
#  'Phantom Brave',
#  'Just Cause',
#  'Championship Motocross 2001 featuring Ricky Carmichael',
#  "Legend of the Guardians: The Owls of Ga'Hoole",
#  'Doshin the Giant',
#  'Star Ocean: Blue Sphere',
#  'Mojo!',
#  'Destroy All Humans! Big Willy Unleashed',
#  'Kamen Rider Ryuki',
#  'Front Mission Alternative',
#  'Cave Story 3D',
#  'Super Dodgeball Brawlers',
#  'Victorious Boxers: Revolution',
#  'Cake Mania 3',
#  '.hack//Link',
#  'The Legend of Heroes II: Prophecy of the Moonlight Witch',
#  'Cranium Kabookii',
#  "Hero's Saga Laevatein Tactics",
#  'Mary-Kate and Ashley: Winners Circle',
#  'OutRun 2',
#  'Soukaigi',
#  'Pipe Mania',
#  'Pirates: The Legend of Black Kat',
#  "Fur Fighters: Viggo's Revenge",
#  'Mr. Driller: Drill Spirits',
#  'Anno 1701: Dawn of Discovery',
#  'Destruction Derby Raw',
#  'Farming Simulator 2012',
#  'NFL Head Coach 09',
#  "Akiba's Trip",
#  'Bravo Air Race',
#  'Gundam: The Battle Master',
#  'Eternal Poison',
#  'X-Blades',
#  'Gungrave: Overdose',
#  'NBA ShootOut 2002',
#  'The Granstream Saga',
#  'Scene It? Bright Lights! Big Screen!',
#  'Micro Machines 64 Turbo',
#  'Eternal Eyes',
#  'The Operative: No One Lives Forever',
#  'Buck Fever',
#  'NCAA Basketball Final Four 97',
#  'Ecco the Dolphin: Defender of the Future',
#  'Earth Defense Force 2: Invaders from Planet Space',
#  'Gyakuten Saiban 2',
#  'Desire',
#  'Valhalla Knights: Eldar Saga',
#  "Tim Burton's The Nightmare Before Christmas: The Pumpkin King",
#  'Enclave',
#  'Dino Crisis 3',
#  'Syberia',
#  'Zoobles! Spring to Life!',
#  "Master Jin Jin's IQ Challenge",
#  'Power Gig: Rise of the SixString',
#  'Agile Warrior F-111X',
#  'NCIS',
#  'Reality Fighters',
#  "Cabela's African Safari",
#  'Super Puzzle Fighter II Turbo',
#  'Ninjatown',
#  'Hard Rock Casino',
#  'Doukyuusei',
#  'Science Papa',
#  'MySims Collection',
#  'Cities: Skylines',
#  'The History Channel: Civil War - A Nation Divided',
#  'Cyber Sled',
#  'Puyo Puyo!! 20th Anniversary',
#  'Shining Soul',
#  'Littlest Pet Shop: Spring',
#  'The Amazing Race',
#  'Alvin and the Chipmunks',
#  'In the Hunt',
#  'BlazBlue: Chrono Phantasma Extend',
#  'Alone in the Dark: Inferno',
#  'Rogue Warrior',
#  'Fear Factor: Unleashed',
#  'Vampire Moon: The Mystery of the Hidden Sun',
#  'Touch My Katamari',
#  "MotoGP '06",
#  '7th Dragon',
#  'Cruise Ship Vacation Games',
#  'Learn Math',
#  'Nitrobike',
#  'Magnetica',
#  'UEFA Euro 2004: Portugal',
#  'Shining Resonance',
#  'World Tour Soccer 2002',
#  "Let's Play Ballerina",
#  'Wild Earth: African Safari',
#  'Apex',
#  'Kamen Rider Battle: Ganbaride',
#  'Tomb Raider: The Prophecy',
#  'Vampire Night',
#  'Guilty Gear',
#  'Imagine: Fashion Stylist',
#  'Red Orchestra 2: Heroes of Stalingrad',
#  "Deepak Chopra's Leela",
#  "Queen's Gate: Spiral Chaos",
#  'Quick Yoga Training',
#  'Fashion Studio: Paris Collection',
#  'Backyard Soccer',
#  'Nobunaga no Yabou: Tendou',
#  'Castlevania Chronicles',
#  'Suzumiya Haruhi no Tomadoi',
#  'NHL 2K8',
#  'Dokapon Kingdom',
#  'Winter Stars',
#  'The Guy Game',
#  'Baseball Advance',
#  'Shovel Knight',
#  "Hulk Hogan's Main Event",
#  'Euro Truck Simulator 2',
#  'Rumble Roses XX',
#  'Bakugan: Battle Trainer',
#  'Phantom Brave: We Meet Again',
#  'Suite PreCure: Melody Collection',
#  'Venetica',
#  "Disney's Kim Possible: Kimmunicator",
#  'Rugby 15',
#  'Army Men: Green Rogue',
#  'Over the Hedge: Hammy Goes Nuts!',
#  'Fatal Inertia',
#  'Ken to Mahou to Gakuen Mono. 3',
#  'The Flintstones: Bedrock Bowling',
#  'Shining Force III',
#  'Tales of the Heroes: Twin Brave',
#  'WWE Survivor Series',
#  'Super Robot Wars BX',
#  "Nagano Winter Olympics '98",
#  'Destroy All Humans! Path of the Furon',
#  'Winning Post 5',
#  'Midnight Mysteries: The Edgar Allan Poe Conspiracy',
#  'All Star Cheer Squad 2',
#  'Frogger Beyond',
#  'The Unholy War',
#  'Shaman King: Power of Spirit',
#  'Eat Lead: The Return of Matt Hazard',
#  'Soccer Tsuku DS: World Challenge 2010',
#  'Contra III: The Alien Wars',
#  'Dead to Rights: Reckoning',
#  'Diablo II',
#  'NBA 08',
#  'Naruto Shippuden: Kizuna Drive',
#  'Indianapolis 500 Legends',
#  'Illusion of Gaia',
#  'Steel Battalion: Heavy Armor',
#  'Academy of Champions: Soccer',
#  "Sally's Salon",
#  'Lovely Lisa and Friends',
#  'Hasbro Family Fun Pack',
#  'Drakengard 2',
#  'Grand Knights History',
#  'Summon Night: Twin Age',
#  'Sin and Punishment',
#  'NBA Jam 2000',
#  'Castlevania: Legacy of Darkness',
#  'Shimano Xtreme Fishing',
#  'Rally Fusion: Race of Champions',
#  'The House of the Dead',
#  "Smart Boy's Gameroom",
#  'NightCaster',
#  'RollerCoaster Tycoon',
#  'Digimon Racing',
#  'Ape Escape 3',
#  'Last Bronx',
#  'Iridion II',
#  'Momotaro Douchuuki',
#  'Brothers: A Tale of Two Sons',
#  'BlazBlue: Continuum Shift II',
#  'Warcraft III: Reign of Chaos',
#  'Farming Simulator 2011',
#  "Margot's Word Brain",
#  'Spider-Man: Battle for New York',
#  "Pop'n Music Portable",
#  'Otogi: Myth of Demons',
#  'Army Men: Soldiers of Misfortune',
#  'Alter Echo',
#  'Puzzle de Harvest Moon',
#  'Onechanbara: Bikini Samurai Squad',
#  'Metal Max 3',
#  'Hour of Victory',
#  'Monster Hunter Frontier Online',
#  'Shin Megami Tensei: Digital Devil Saga',
#  '7 Wonders of the Ancient World',
#  "Backyard Baseball '09",
#  'Puppies 3D',
#  'Jissen Pachi-Slot Hisshouhou! Aladdin II Evolution',
#  'Mystic Ark',
#  'Sega GT',
#  'Tamagotchi no Pichi Pichi Omisecchi',
#  'Shining Wind',
#  'Assault: Retribution',
#  'Gravity Rush Remastered',
#  'City Crisis',
#  'Advent Rising',
#  'Torino 2006',
#  'The Price is Right: Decades',
#  'The Sky Crawlers: Innocent Aces',
#  'DT Racer',
#  'SimAnimals Africa',
#  'Twister Mania',
#  "Garfield's Fun Fest",
#  '7th Dragon 2020-II',
#  'Doukyuusei 2',
#  'Zenses: Ocean',
#  'Teenage Mutant Ninja Turtles: Arcade Attack',
#  'Left Brain Right Brain 2',
#  'Victorious: Time to Shine',
#  'Aikatsu! 365 Idol Days',
#  'The Stronghold Collection',
#  'Dragon Ball: Origins',
#  'Last Ranker',
#  'Quantum Redshift',
#  'Smash Court Tennis Pro Tournament 2',
#  'Armed and Dangerous',
#  'Adventures to Go!',
#  'Conduit 2',
#  'Supremacy MMA',
#  'Horse Life',
#  'Puella Magi Madoka Magica Portable',
#  'Ninja Reflex',
#  "Peter Jacobsen's Golden Tee Golf",
#  'Calling',
#  'Marvel Avengers: Battle for Earth',
#  'NHL 2K7',
#  'Criticom',
#  'After Hours Athletes',
#  'Worms 3D',
#  'Clock Tower: The First Fear',
#  'Godzilla Unleashed: Double Smash',
#  'Star Trek: Conquest',
#  'Strikers 1945',
#  'Ochaken no Heya DS',
#  'Galidor: Defenders of the Outer Dimension',
#  'Blackwater',
#  'Pryzm Chapter One: The Dark Unicorn',
#  'Gundam Battle Royale',
#  'Solitaire & Mahjong',
#  'Guilty Gear X',
#  'Deadliest Catch: Sea of Chaos',
#  "Disney's PK: Out of the Shadows",
#  'Echo Night',
#  'Gladiator Begins',
#  'Magic: The Gathering - Battlemage',
#  "The King of Fighters '94",
#  'Puzzle Quest 2',
#  'All Kamen Rider: Rider Generation',
#  "Guardian's Crusade",
#  'Undead Knights',
#  'Makai Kingdom: Chronicles of the Sacred Tome',
#  'Gotouchi Tetsudou: Gotouchi Chara to Nihon Zenkoku no Tabi',
#  'Record of Agarest War Zero',
#  'Lunar: Dragon Song',
#  'Voodoo Vince',
#  'Bodycount',
#  'Gundam Memories: Tatakai no Kioku',
#  'Neopets Petpet Adventures: The Wand of Wishing',
#  'Virtua Fighter CG Portrait Series Vol.4: Pai Chan',
#  'Chase: Hollywood Stunt Driver',
#  'Crush3D',
#  'Zathura',
#  'Lovely Lisa',
#  'Cel Damage',
#  'Go! Sudoku',
#  'My Chinese Coach',
#  'Atelier Annie: Alchemists of Sera Island',
#  'Looney Tunes: Sheep Raider',
#  'Yard Sale Hidden Treasures: Sunnyville',
#  'Harvest Moon 2 GBC',
#  'Lost in Shadow',
#  'Gallop Racer 2000',
#  'Macross Triangle Frontier',
#  'Petz Fantasy: Moonlight Magic',
#  'Gundam Breaker 3',
#  'My Farm Around the World',
#  'Fat Princess: Fistful of Cake',
#  'Zubo',
#  'NFL QB Club 2001',
#  'Earthworm Jim 3D',
#  'Rocket: Robot on Wheels',
#  'Animal Genius',
#  'Zenses: Rainforest',
#  'Skate City Heroes',
#  'Mytran Wars',
#  'Fate/Extra CCC',
#  'MTV Sports: Pure Ride',
#  'Burning Road',
#  'IndyCar Series',
#  'Famicom Mini: TwinBee',
#  'Gladiator: Sword of Vengeance',
#  'PixelJunk Monsters Deluxe',
#  'Sacred 3',
#  'Onimusha: Blade Warriors',
#  'Akuji the Heartless',
#  '7 Days to Die',
#  'Everybody Dance',
#  'Psychonauts',
#  'HardBall 5',
#  'Airborne Troops: Countdown to D-Day',
#  'Marvel Trading Card Game',
#  'One Piece: Super Grand Battle! X',
#  'Self-Defense Training Camp',
#  'Battles of Prince of Persia',
#  'Deca Sports Extreme',
#  "Cruis'n",
#  'Hatsune Miku: Project Diva X',
#  'Crime Killer',
#  'Dementium II',
#  'Don Bradman Cricket 14',
#  'USA Today Crossword Challenge',
#  'Raiden IV',
#  'Charm Girls Club: My Perfect Prom',
#  'Harukanaru Augusta 2: Masters',
#  'Mobil 1 Rally Championship',
#  'Love Live! School Idol Paradise',
#  'Rugrats: Totally Angelica',
#  'NFL Tour',
#  'CSI: Crime Scene Investigation',
#  'Hanagumi Taisen Columns',
#  'Get Up and Dance',
#  "Merv Griffin's Crosswords",
#  'Ultimate Puzzle Games: Sudoku Edition',
#  'Tokyo Twilight Ghost Hunters',
#  "NHL Powerplay '96",
#  'Thousand Arms',
#  'Darkspore',
#  'Armored Core: Verdict Day',
#  'Harvey Birdman: Attorney at Law',
#  'ASH: Archaic Sealed Heat',
#  'Happy Feet Two',
#  'Dorabase 2: Nettou Ultra Stadium',
#  'Die Hard: Vendetta',
#  'GT Advance 2: Rally Racing',
#  "A Witch's Tale",
#  "Dead Man's Hand",
#  'Smash Cars',
#  'NASCAR 07',
#  "Pac 'n Roll",
#  'Mechanic Master',
#  'ToeJam & Earl III: Mission to Earth',
#  "LEGO Knights' Kingdom",
#  'Retro Game Challenge',
#  'NBA Jam 2002',
#  'Every Extend Extra',
#  'Girl Time',
#  'Ultimate Mortal Kombat',
#  'BoomBots',
#  'Monster Madness: Battle for Suburbia',
#  'World Championship Rugby',
#  'Shin Sangoku Musou: Multi Raid 2',
#  'Mega Man Battle Chip Challenge',
#  'Puyo Puyo Tetris',
#  'The Settlers',
#  'Family Fun Football',
#  'Ring of Red',
#  'Cold Winter',
#  'The Hardy Boys: Treasure on the Tracks',
#  'Stubbs the Zombie in Rebel Without a Pulse',
#  'Batman: Dark Tomorrow',
#  'Ping Pals',
#  'Blood Drive',
#  'Digimon World DS',
#  'Mass Destruction',
#  "Queen's Blade: Spiral Chaos",
#  'Sega Touring Car Championship',
#  "JASF: Jane's Advanced Strike Fighters",
#  'Cake Mania',
#  'Cold Fear',
#  'Zangeki no Reginleiv',
#  'Fabulous Finds',
#  'Vacation Sports',
#  'Pimp My Ride',
#  'Invizimals: The Lost Tribes',
#  "Let's Play Garden",
#  'Murakumo: Renegade Mech Pursuit',
#  'Samurai Warriors 4-II',
#  'WireWay',
#  'Gun Metal',
#  "John Daly's ProStroke Golf",
#  'The Hardy Boys: The Hidden Theft',
#  'Pac-Man and the Ghostly Adventures 2',
#  'Gem Quest: 4 Elements',
#  'Funky Barn',
#  'Pac-Man Pinball Advance',
#  'Pocket Pets',
#  'Yu Yu Hakusho: Tournament Tactics',
#  'To Heart 2: Dungeon Travelers',
#  'Criminal Girls: Invite Only',
#  'Truth or Lies',
#  'Kousoku Card Battle: Card Hero',
#  'AirForce Delta Strike',
#  'Capcom vs. SNK 2 EO',
#  'Spyborgs',
#  'American Girl: Julie Finds a Way',
#  'Contra Advance: The Alien Wars EX',
#  'The History Channel: Battle for the Pacific',
#  '18 Wheels of Steel: Extreme Trucker 2',
#  'Army Men: RTS',
#  'Mobile Suit Gundam: MS Sensen 0079',
#  'Maximum Force',
#  'Worms Forts: Under Siege',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Totally Spies! Totally Party',
#  'Smash Court Tennis 3',
#  'Naruto Shippuden: Naruto vs. Sasuke',
#  'DualPenSports',
#  'Odama',
#  'FlatOut: Ultimate Carnage',
#  'Mobile Light Force 2',
#  'Naval Ops: Warship Gunner',
#  'Soma Bringer',
#  'Sesame Street: Ready, Set, Grover!',
#  'Paws & Claws Pet Vet: Australian Adventures',
#  'Trauma Center: Under the Knife 2',
#  'The Croods: Prehistoric Party!',
#  'Lunacy',
#  'Snowboard Kids 2',
#  'Chameleon Twist',
#  'Top Gear Rally 2',
#  'Fighting Force 64',
#  'BlazBlue: Calamity Trigger Portable',
#  'Virtual Hydlide',
#  'Tales of the World: Reve Unitia',
#  'The Bachelor: The Videogame',
#  'Toukiden 2',
#  'Dreamer Series: Top Model',
#  'The First Templar',
#  'Child of Light',
#  'SingStar Guitar',
#  'Busou Shinki: Battle Masters Mk. 2',
#  'Fairy Tail: Portable Guild',
#  'Brunswick Circuit Pro Bowling 2',
#  'D',
#  'Ennichi no Tatsujin',
#  'Squinkies 2: Adventure Mall Surprize!',
#  'Power Pocket Koushien',
#  'Gravity Games Bike: Street Vert Dirt',
#  'Princess Debut',
#  'Derby Stallion P',
#  'UFC: Tapout 2',
#  'Kamen Rider: Battride War II',
#  'Imagine: Soccer Captain',
#  'F1 Career Challenge',
#  'Taiko no Tatsujin: V Version',
#  'Pariah',
#  'Fatal Frame 2: Wii Edition',
#  'Dancing on Ice',
#  'Banjo-Pilot',
#  ...]

# %%
# remove duplicates from the list of passes
# passes_copy = passes.copy()
# passed_ids = set([k.get('id') for k in passes])
# temp = []
# for i, j in enumerate(passes_copy):
#     if j.get('id') in passed_ids and j.get('id') not in temp:
#         temp.append(j.get('id'))
#     elif j.get('id') in passed_ids and j.get('id') in temp:
#         passes.remove(j)
# len(passes)
# Out:
# 7

# %%
# clear temp lists
# passes_temp, passes_copy = [], []
# len(passes_temp), len(passes_copy)
# Out:
# (0, 0)

# %%
# [passes[i].get('name') for i, j in enumerate(fails)]
# fails[::-1]
# Out:
# [('The Adventures of Jimmy Neutron Boy Genius vs. Jimmy Negatron',
#   'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 2013', 'name equals'),
#  ('Inazuma Eleven GO 3: Galaxy', 'name equals'),
#  ('DS Bungaku Zenshuu', 'name equals'),
#  ('Love Plus', 'name equals'),
#  ('Tomba!', 'name equals'),
#  ('Zoo Tycoon 2: Ultimate Collection', 'name equals'),
#  ('NPPL: Championship Paintball 2009', 'name equals'),
#  ("Jikkyou Powerful Pro Yakyuu '99 Ketteiban", 'name equals'),
#  ('Littlest Pet Shop: Friends', 'name equals'),
#  ("A.C.E.: Another Century's Episode R", 'name equals'),
#  ('Create', 'name equals'),
#  ('Reload: Target Down', 'name equals'),
#  ('Sonic X: Game Boy Advance Video Volume 1', 'name equals'),
#  ('And1 Streetball', 'name equals'),
#  ('Fish Tycoon', 'name equals'),
#  ('Imagine: Fashion Party', 'name equals'),
#  ('Dynasty Warriors 7: Xtreme Legends', 'name equals'),
#  ('Operation Armored Liberty', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 2010', 'name equals'),
#  ('My Virtual Tutor: Reading Adventure Kindergarten to First', 'name equals'),
#  ('Superman Returns', 'name equals'),
#  ('Super Collapse! 3', 'name equals'),
#  ('InuYasha: Feudal Combat', 'name equals'),
#  ('Super Nazo Puyo: Ruruu no Ruu', 'name equals'),
#  ('Are You Smarter than a 5th Grader? Game Time', 'name equals'),
#  ("Cake Mania 2: Jill's Next Adventure!", 'name equals'),
#  ('Ace Attorney 6', 'name equals'),
#  ("Jikkyou Powerful Pro Yakyuu '98 Ketteiban", 'name equals'),
#  ('Reign of Fire', 'name equals'),
#  ('Dora the Explorer: Dora Saves the Crystal Kingdom', 'name equals'),
#  ('F1 2016 (Codemasters)', 'name equals'),
#  ('Fire Emblem: Shin Monshou no Nazo Hikari to Kage no Eiyuu', 'name equals'),
#  ('Final Fantasy XI: Ultimate Collection', 'name equals'),
#  ('XGIII: Extreme G Racing', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 2', 'name equals'),
#  ('Rock Revolution', 'name equals'),
#  ('Summer Athletics: The Ultimate Challenge (US sales)', 'name equals'),
#  ('MotoGP', 'name equals'),
#  ('Ben 10 Triple Pack', 'name equals'),
#  ('Tohoku Daigaku Karei Igaku Kenkyuusho - Kawashima Ryuuta Kyouju Kanshuu - Mono Sugoku Nou o Kitaeru 5-Funkan no Oni Training',
#   'name equals'),
#  ('NBA Jam 99', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 5', 'name equals'),
#  ("NBA In The Zone '98", 'name equals'),
#  ('Reader Rabbit Kindergarten', 'name equals'),
#  ('Medarot 3: Kabuto / Kuwagata Version', 'name equals'),
#  ('Yu-Gi-Oh! The Sacred Cards (JP weekly sales)', 'name equals'),
#  ('Fushigi no Dungeon: Fuurai no Shiren GB: Tsukikagemura no Kaibutsu',
#   'name equals'),
#  ('Bridge', 'name equals'),
#  ('NickToons: Racing', 'name equals'),
#  ('Rocky: Legends', 'name equals'),
#  ('Slam Dunk: Yonkyo Taiketsu!!', 'name equals'),
#  ('Bishoujo Senshi Sailormoon R', 'name equals'),
#  ('Baten Kaitos: Eternal Wings and the Lost Ocean', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu Portable 4', 'name equals'),
#  ('Gunship', 'name equals'),
#  ('Hatsune Miku: Project Diva f', 'name equals'),
#  ('Burstrick: Wake Boarding!!', 'name equals'),
#  ('Littlest Pet Shop: Beach Friends', 'name equals'),
#  ('Indy 500', 'name equals'),
#  ('Zumba Fitness: World Party', 'name equals'),
#  ('Resident Evil 2: Dual Shock Edition', 'name equals'),
#  ('The Legend of Zelda: The Minish Cap(weekly JP sales)', 'name equals'),
#  ('Mr. Do!', 'name equals'),
#  ('Moero! Nekketsu Rhythm Damashii: Osu! Tatakae! Ouendan! 2', 'name equals'),
#  ('Nichibutsu Arcade Classics', 'name equals'),
#  ('ExciteBots: Trick Racing', 'name equals'),
#  ('Kobitodzukan: Kobito Kansatsu Set', 'name equals'),
#  ('Mobile Suit Gundam Side Story I: Senritsu no Blue', 'name equals'),
#  ('Castlevania: Aria of Sorrow', 'name equals'),
#  ('Power Pro Kun Pocket 3', 'name equals'),
#  ('One Piece Unlimited Cruise 1: The Treasure Beneath the Waves',
#   'name equals'),
#  ('Puppeteer', 'name equals'),
#  ('AC/DC LIVE: Rock Band Track Pack', 'name equals'),
#  ('Yu-Gi-Oh! Monster Capsule Breed & Battle', 'name equals'),
#  ('Pokemon Box: Ruby & Sapphire', 'name equals'),
#  ('Deer Hunter', 'name equals'),
#  ('Civilization II', 'name equals'),
#  ('iCarly 2: iJoin The Click!', 'name equals'),
#  ('Real Pool', 'name equals'),
#  ('NHL Hitz 20-03', 'name equals'),
#  ('UEFA Euro 2016', 'name equals'),
#  ("Dragon Quest Heroes II: Twin Kings and the Prophecy's End", 'name equals'),
#  ('NBA In The Zone', 'name equals'),
#  ('Shadows of the Damned', 'name equals'),
#  ('Wild ARMs 5', 'name equals'),
#  ('Dead or Alive', 'name equals'),
#  ('Virtua Fighter 5 Online', 'name equals'),
#  ('Hot Wheels: Track Attack', 'name equals'),
#  ('Shrek: Ogres & Dronkeys', 'name equals'),
#  ('Mission: Impossible - Operation Surma', 'name equals'),
#  ('Remington Super Slam Hunting: Africa', 'name equals'),
#  ('MX SuperFly featuring Ricky Carmichael', 'name equals'),
#  ('Lord of Darkness', 'name equals'),
#  ('Jackass the Game', 'name equals'),
#  ('Jissen Pachi-Slot Hisshouhou! Moujuu-Oh S', 'name equals'),
#  ('Arcade Hits: Frisky Tom', 'name equals'),
#  ('Polaris', 'name equals'),
#  ('F/A-18F Super Hornet', 'name equals'),
#  ("The King of Fighters '95", 'name equals'),
#  ('Pro Evolution Soccer 2017', 'name equals'),
#  ('Netsu Chu! Pro Yakyuu 2003', 'name equals'),
#  ('Yu-Gi-Oh! Double Pack', 'name equals'),
#  ('Haven: Call of the King', 'name equals'),
#  ("Tigger's Honey Hunt", 'name equals'),
#  ('International Superstar Soccer', 'name equals'),
#  ('Super Fire ProWrestling X', 'name equals'),
#  ('DeathSmiles', 'name equals'),
#  ('SingStar Country', 'name equals'),
#  ('Earthworm Jim', 'name equals'),
#  ('Battle & Get! Pokemon Typing DS', 'name equals'),
#  ('Family Guy: Back to the Multiverse', 'name equals'),
#  ('El Shaddai: Ascension of the Metatron', 'name equals'),
#  ('Power Pro Kun Pocket 11', 'name equals'),
#  ('BeatMania Append 4thMix: The beat goes on', 'name equals'),
#  ('I Spy: Spooky Mansion', 'name equals'),
#  ("Penguin no Mondai: Saikyou Penguin Densetsu! A Penguin's Troubles",
#   'name equals'),
#  ('Rayman 3: Hoodlum Havoc', 'name equals'),
#  ('Namco Museum Vol.2', 'name equals'),
#  ('Final Fantasy X-2: International + Last Mission', 'name equals'),
#  ("Surf's Up", 'name equals'),
#  ('Snowboarding', 'name equals'),
#  ('Feel the Magic XY/XX', 'name equals'),
#  ('The Urbz: Sims In the City (US weekly sales)', 'name equals'),
#  ('Sakura Wars 4: Koi Seyo,Otome', 'name equals'),
#  ('SD Gundam Gaiden: Knight Gundam Monogatari: Ooinaru Isan', 'name equals'),
#  ('Pirates of the Caribbean', 'name equals'),
#  ('DX Game of Life', 'name equals'),
#  ("Ken Griffey Jr.'s Slugfest", 'name equals'),
#  ('Viz', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 8', 'name equals'),
#  ('Fast Food', 'name equals'),
#  ('Ys: Memories of Celceta', 'name equals'),
#  ('The Smurfs: Dance Party', 'name equals'),
#  ('Starhawk', 'name equals'),
#  ('Itadaki Street 2: Neon Sign wa Bara Iro ni', 'name equals'),
#  ('Atelier Iris 3: Grand Phantasm (US Sales)', 'name equals'),
#  ('SD Gundam G Century', 'name equals'),
#  ("J-League Victory Goal '96", 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 2000 Kaimakuban', 'name equals'),
#  ('Punch-Out!!', 'name equals'),
#  ('One Piece Unlimited Cruise 2: Awakening of a Hero', 'name equals'),
#  ('Prince of Persia: Rival Swords', 'name equals'),
#  ('Kurohyou: Ryu ga Gotoku Shinshou', 'name equals'),
#  ('Outlaw Golf', 'name equals'),
#  ('Guardian Heroes', 'name equals'),
#  ('The Godfather: Dons Edition', 'name equals'),
#  ('Power Pro Kun Pocket 4', 'name equals'),
#  ('Junior Brain Trainer 2', 'name equals'),
#  ('The BIGS 2', 'name equals'),
#  ('Syphon Filter: Dark Mirror', 'name equals'),
#  ('Mah Jong Quest: Expeditions', 'name equals'),
#  ('MLB SlugFest Loaded', 'name equals'),
#  ('Hamster Tarou', 'name equals'),
#  ('Future Cop L.A.P.D.', 'name equals'),
#  ('Power Pro Kun Pocket 10', 'name equals'),
#  ('Harvest Moon DS Cute (US sales)', 'name equals'),
#  ('Power Pro Kun Pocket 6', 'name equals'),
#  ('Dragon Quest Builders: Revive Alefgard', 'name equals'),
#  ('Taiko no Tatsujin Wii: Minna de Party * 3-Yome!', 'name equals'),
#  ('Star Ocean 5: Integrity and Faithlessness', 'name equals'),
#  ('Far East of Eden Zero', 'name equals'),
#  ('Call of Duty: Modern Warfare 3: Defiance', 'name equals'),
#  ('Capcom Classics Collection Remixed', 'name equals'),
#  ('Star Gladiator Episode: I Final Crusade', 'name equals'),
#  ('Rabbids: Alive & Kicking', 'name equals'),
#  ('Shin Megami Tensei: Persona 2: Innocent Sin', 'name equals'),
#  ('Yu Yu Hakusho Ghost Files: Spirit Detective', 'name equals'),
#  ('One Piece Unlimited Cruise SP', 'name equals'),
#  ('Nounai Aeshe: IQ Suppli DS', 'name equals'),
#  ('Daikaijyuu Monogatari', 'name equals'),
#  ('Fossil Fighters (JP sales)', 'name equals'),
#  ('Toukiden Kiwami', 'name equals'),
#  ('Dynasty Warriors 8: Xtreme Legends', 'name equals'),
#  ('Decathlete', 'name equals'),
#  ('Super Robot Taisen OG: Original Generations Gaiden', 'name equals'),
#  ("Famista '91", 'name equals'),
#  ('The Dukes of Hazzard II: Daisy Dukes It Out', 'name equals'),
#  ('Super Robot Taisen W', 'name equals'),
#  ('Rhythm Tengoku', 'name equals'),
#  ('Batman: The Brave and the Bold the Videogame', 'name equals'),
#  ('WarCraft II: The Dark Saga', 'name equals'),
#  ('ExerBeat', 'name equals'),
#  ('Might & Magic Heroes VI', 'name equals'),
#  ('Heart of Darkness', 'name equals'),
#  ('Dynasty Warriors 4 Empires', 'name equals'),
#  ('Power Rangers: Time Force', 'name equals'),
#  ('Momotarou Dentetsu Happy', 'name equals'),
#  ('Live A Live', 'name equals'),
#  ('Shin Super Robot Taisen Special Disk', 'name equals'),
#  ('The Conveni: Ano Machi wo Dokusen Seyo', 'name equals'),
#  ('Sega Smash Pack', 'name equals'),
#  ('From TV Animation One Piece: Grand Battle! 3', 'name equals'),
#  ('Shin Momotarou Densetsu', 'name equals'),
#  ('Dragon Quest Monsters: Battle Road Victory', 'name equals'),
#  ("Disney's Extreme Skate Adventure", 'name equals'),
#  ('Tetris 2 + Bombliss', 'name equals'),
#  ('SpongeBob SquarePants: Double Pack', 'name equals'),
#  ('Cartoon Network Collection: Game Boy Advance Video Platinum Edition',
#   'name equals'),
#  ('No.1 Muscle Ranking - Kinniku Banzuke Vol. 1: Oregasaikyouno Otokoda!',
#   'name equals'),
#  ('Seaman: Kindan no Pet - Gaze Hakushi no Jikken Shima', 'name equals'),
#  ("Gold's Gym: Cardio Workout (Others sales)", 'name equals'),
#  ('FIFA 2001 Major League Soccer', 'name equals'),
#  ('Fortress', 'name equals'),
#  ('DiRT Rally', 'name equals'),
#  ('Nagano Winter Olympics 98', 'name equals'),
#  ('Singularity', 'name equals'),
#  ('Go, Diego, Go!: Great Dinosaur Rescue', 'name equals'),
#  ('Final Fantasy XI', 'name equals'),
#  ('Naruto: Ultimate Ninja (JP sales)', 'name equals'),
#  ('Harvest Moon: Back to Nature', 'name equals'),
#  ('ESPN X-Games Pro Boarder', 'name equals'),
#  ('Prey', 'name equals'),
#  ('Dragon Quest Monsters 1·2', 'name equals'),
#  ("Bust-A-Move '99", 'name equals'),
#  ('Momotarou Dentetsu 20-Shuunen', 'name equals'),
#  ('One Piece: Romance Dawn - Bouken no Yoake', 'name equals'),
#  ('J Stars Victory Vs.', 'name equals'),
#  ('Dr. Mario / Puzzle League', 'name equals'),
#  ('Fireball', 'name equals'),
#  ('Karaoke Revolution Presents American Idol Encore 2', 'name equals'),
#  ('Frogger II: Threeedeep!', 'name equals'),
#  ('Teen Titans', 'name equals'),
#  ('Samurai Warriors 2: Xtreme Legends (JP sales)', 'name equals'),
#  ('Dragon Ball Z: Extreme Butoden', 'name equals'),
#  ('NBA Live 96', 'name equals'),
#  ('DX Game of Life 2', 'name equals'),
#  ('Carnival Games: Monkey See, Monkey Do!', 'name equals'),
#  ('Zaidan Houjin Nippon Kanji Nouryoku Kentei Kyoukai Kounin: KanKen DS 2 + Jouyou Kanji Jiten',
#   'name equals'),
#  ('MySims SkyHeroes', 'name equals'),
#  ('Naruto: Gekito Ninja Taisen! 4', 'name equals'),
#  ('Power Rangers: Ninja Storm', 'name equals'),
#  ('NCAA GameBreaker 2001', 'name equals'),
#  ('Sakura Wars 3: Paris wa Moeteiru ka', 'name equals'),
#  ('Parodius', 'name equals'),
#  ('My Baby: First Steps', 'name equals'),
#  ('Goosebumps HorrorLand', 'name equals'),
#  ('Battle Dodge Ball', 'name equals'),
#  ('DECA Sports Freedom', 'name equals'),
#  ('BattleTanx', 'name equals'),
#  ('FIFA Street 3', 'name equals'),
#  ('Capcom Classics Collection Reloaded', 'name equals'),
#  ('Extra Bases', 'name equals'),
#  ('Legends of Wrestling II', 'name equals'),
#  ("Kelly Slater's Pro Surfer", 'name equals'),
#  ('BeatMania Append GottaMix', 'name equals'),
#  ("Disney's Treasure Planet", 'name equals'),
#  ('Family Party: 90 Great Games Party Pack', 'name equals'),
#  ('Chicken Blaster', 'name equals'),
#  ('WWE Wrestlemania XIX', 'name equals'),
#  ('Untold Legends: The Warriors Code', 'name equals'),
#  ('Digimon World: Dawn / Dusk', 'name equals'),
#  ('Transformers: Revenge of the Fallen (DS Versions)', 'name equals'),
#  ('Sengoku Musou 3 Z', 'name equals'),
#  ('Night at the Museum: Battle of the Smithsonian', 'name equals'),
#  ('MXRider', 'name equals'),
#  ('Modnation Racers: Road Trip', 'name equals'),
#  ('Pony Friends 2', 'name equals'),
#  ('The Sims 3: Town Life Stuff', 'name equals'),
#  ('Herbie: Fully Loaded', 'name equals'),
#  ('Zoo Tycoon (2013)', 'name equals'),
#  ('Jonah Lomu Rugby Challenge', 'name equals'),
#  ('Tiny Tank', 'name equals'),
#  ("Smart Girl's Party Game", 'name equals'),
#  ('Point Blank', 'name equals'),
#  ('Momotarou Dentetsu DS: Tokyo & Japan', 'name equals'),
#  ('Football Manager Handheld 2008', 'name equals'),
#  ('Silent Hill HD Collection', 'name equals'),
#  ('Dynasty Warriors 6 Empires', 'name equals'),
#  ("Alien's Return", 'name equals'),
#  ('Super Bust-A-Move', 'name equals'),
#  ('Iron Storm', 'name equals'),
#  ("Tim Burton's The Nightmare Before Christmas: Oogie's Revenge",
#   'name equals'),
#  ('Freeway', 'name equals'),
#  ('Conan', 'name equals'),
#  ('WipEout 3', 'name equals'),
#  ('Dynasty Warriors 5 Empires', 'name equals'),
#  ('The Wild Thornberrys Movie', 'name equals'),
#  ('Risk / Battleship / Clue', 'name equals'),
#  ('Charlie and the Chocolate Factory', 'name equals'),
#  ('EverGrace', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 7', 'name equals'),
#  ('Aggressive Inline', 'name equals'),
#  ('From TV Animation One Piece: Tobidase Kaizokudan!', 'name equals'),
#  ('The Fairly Odd Parents: Shadow Showdown', 'name equals'),
#  ('Harry Potter and the Deathly Hallows - Part 2', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 2000', 'name equals'),
#  ('Dragon Ball Z: Budokai Tenkaichi 2 (JP sales)', 'name equals'),
#  ('One Piece: Gigant Battle 2 Shin Sekai', 'name equals'),
#  ('Persona 2: Eternal Punishment', 'name equals'),
#  ('Star Fox: Zero', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 13', 'name equals'),
#  ('Batman: Rise of Sin Tzu', 'name equals'),
#  ('Momotarou Dentetsu 12', 'name equals'),
#  ('Vancouver 2010 - The Official Video Game of the Olympic Winter Games',
#   'name equals'),
#  ('Sentouchu: Densetsu no Shinobi to Survival Battle!', 'name equals'),
#  ('Remember Me', 'name equals'),
#  ("Cabela's Outdoor Adventures (2006)", 'name equals'),
#  ('Blasto', 'name equals'),
#  ('SOCOM: Tactical Strike', 'name equals'),
#  ('CSI: Deadly Intent - The Hidden Cases', 'name equals'),
#  ('Formula 1 Championship Edition', 'name equals'),
#  ('Wonder Pets! Save the Animals!', 'name equals'),
#  ('Mega Man Zero Collection', 'name equals'),
#  ('Ganbare Goemon 3: Shishi Jyuurokubei no Karakuri Manji Katame',
#   'name equals'),
#  ('Toriko: Gourmet Survival!', 'name equals'),
#  ('DanceDanceRevolution', 'name equals'),
#  ('Frogs And Flies', 'name equals'),
#  ('Chicken Shoot', 'name equals'),
#  ('Ryu Ga Gotoku Kenzan!', 'name equals'),
#  ('Dai-2-Ji Super Robot Taisen Z Saisei-hen', 'name equals'),
#  ('James Bond 007: Legends', 'name equals'),
#  ("J-League Pro Soccer Club o Tsukurou '04", 'name equals'),
#  ('Naruto: Ultimate Ninja 3 (JP sales)', 'name equals'),
#  ('ATV/Monster Truck Mayhem', 'name equals'),
#  ('Hamster Club 3', 'name equals'),
#  ('Senran Kagura Shinovi Versus: Sh?jo-tachi no Sh?mei', 'name equals'),
#  ("Saban's Power Rangers: Lightspeed Rescue", 'name equals'),
#  ('Mystical Ninja starring Goemon', 'name equals'),
#  ('Jurassic Park', 'name equals'),
#  ('NHL 2K10', 'name equals'),
#  ("Cubix Robots for Everyone: Clash 'n' Bash", 'name equals'),
#  ('Press Your Luck 2010 Edition', 'name equals'),
#  ('Valkyrie Profile: Lenneth', 'name equals'),
#  ('NARC', 'name equals'),
#  ('Robots', 'name equals'),
#  ('Kamaitachi no Yoru 2', 'name equals'),
#  ('Yuu Yuu Hakusho', 'name equals'),
#  ('Super Fire ProWrestling Special', 'name equals'),
#  ('Bejeweled 3', 'name equals'),
#  ('ESPN X Games Skateboarding', 'name equals'),
#  ('Nonomura Byoin no Hitobito', 'name equals'),
#  ('Zero4 Champ RR', 'name equals'),
#  ("Mini-Yonku GB: Let's & Go!!", 'name equals'),
#  ('Transformers: Dark of the Moon', 'name equals'),
#  ('Shin Megami Tensei II', 'name equals'),
#  ('Bottom of the 9th', 'name equals'),
#  ('FIFA Street 2', 'name equals'),
#  ('Super Robot Taisen EX', 'name equals'),
#  ('NFL Street 2 Unleashed', 'name equals'),
#  ('Slime MoriMori Dragon Quest: Shougeki No Shippo Dan', 'name equals'),
#  ('Bionic Commando', 'name equals'),
#  ('Medieval II: Total War Gold Edition', 'name equals'),
#  ('Command & Conquer: Red Alert 3 Ultimate Edition', 'name equals'),
#  ('Custom Robo', 'name equals'),
#  ('Scooby-Doo! Classic Creep Capers', 'name equals'),
#  ('Turok: Rage Wars', 'name equals'),
#  ('Fushigi no Dungeon: Furai no Shiren 2 - Oni Shuurai! Shiren Shiro!',
#   'name equals'),
#  ('Yarudora Series Vol.1: Double Cast', 'name equals'),
#  ('Panzer Dragoon', 'name equals'),
#  ('Super Formation Soccer 94', 'name equals'),
#  ('High Heat Major League Baseball 2003', 'name equals'),
#  ("Cabela's Deer Hunt 2005 Season", 'name equals'),
#  ('Phantasy Star Portable 2: Infinity', 'name equals'),
#  ('Digging for Dinosaurs', 'name equals'),
#  ('SAW', 'name equals'),
#  ('ESPN: Sports Connection', 'name equals'),
#  ('Solaris', 'name equals'),
#  ('Petz Rescue: Ocean Patrol', 'name equals'),
#  ('The House of the Dead: Overkill - Extended Cut', 'name equals'),
#  ('The Legend of Spyro: A New Beginning', 'name equals'),
#  ('Mobile Suit Gundam: Extreme VS Full Boost', 'name equals'),
#  ('EyeToy Play 2', 'name equals'),
#  ('Gravitar', 'name equals'),
#  ('Hangman', 'name equals'),
#  ('ZhuZhu Pets: Featuring The Wild Bunch', 'name equals'),
#  ('Etrian Odyssey IV: Legends of the Titans', 'name equals'),
#  ('Pokemon Channel', 'name equals'),
#  ('Dai-4-Ji Super Robot Taisen', 'name equals'),
#  ('Guitar Hero On Tour: Modern Hits', 'name equals'),
#  ('MediEvil II', 'name equals'),
#  ('Silent Scope', 'name equals'),
#  ('Mobile Suit Gundam version 2.0', 'name equals'),
#  ('Risk: Global Domination', 'name equals'),
#  ('Lilo & Stitch 2: Hämsterviel Havoc', 'name equals'),
#  ('Phoenix Wright: Ace Attorney - Dual Destinies', 'name equals'),
#  ('Raving Rabbids: Travel in Time 3D', 'name equals'),
#  ('Mobile Suit Gundam: Giren no Yabou Zeon Dokuritsu Sensouden',
#   'name equals'),
#  ('Get Fit with Mel B', 'name equals'),
#  ('God Eater 2: Rage Burst', 'name equals'),
#  ('Wario Land II (GBC)', 'name equals'),
#  ('Super Soccer', 'name equals'),
#  ('Phantasy Star Ø', 'name equals'),
#  ('One Piece: Unlimited World Red', 'name equals'),
#  ('Evil Dead: Fistfull of Boomstick', 'name equals'),
#  ('Jam Sessions: Sing and Play Guitar (US sales)', 'name equals'),
#  ('Samurai Warriors Chronicles', 'name equals'),
#  ('Hooked! Again: Real Motion Fishing', 'name equals'),
#  ('Junior Classic Games', 'name equals'),
#  ('Ice Age 2: The Meltdown', 'name equals'),
#  ('Madden NFL Football', 'name equals'),
#  ('From TV Animation One Piece: Yume no Lufy Kaizokudan Tanjou!',
#   'name equals'),
#  ('Chessmaster', 'name equals'),
#  ('MotoGP 08', 'name equals'),
#  ('SpongeBob vs The Big One: Beach Party Cook Off', 'name equals'),
#  ('Super Fire ProWrestling', 'name equals'),
#  ("Sesame Street: Elmo's A-to-Zoo Adventure", 'name equals'),
#  ('Blood Omen 2', 'name equals'),
#  ('Jampack Winter 2003 (RP-T)', 'name equals'),
#  ('Dawn of Discovery', 'name equals'),
#  ('Chibi-Robo! Plug into Adventure!', 'name equals'),
#  ('Yoshi Touch & Go', 'name equals'),
#  ('Tear Ring Saga Yutona Eiyuu Senki', 'name equals'),
#  ('Metal Gear Solid: The Legacy Collection', 'name equals'),
#  ('Donkey Konga 2', 'name equals'),
#  ('Thrasher Presents: Skate and Destroy', 'name equals'),
#  ('Ener-G: Gym Rockets', 'name equals'),
#  ('Fire Emblem: Fuuin no Tsurugi', 'name equals'),
#  ('Rune Factory: Frontier', 'name equals'),
#  ('The House of The Dead III', 'name equals'),
#  ("Disney's Brother Bear", 'name equals'),
#  ('GRID 2', 'name equals'),
#  ('Fantastic Four: Rise of the Silver Surfer', 'name equals'),
#  ('Suzuki TT Superbikes', 'name equals'),
#  ('Naruto: Path of the Ninja', 'name equals'),
#  ('Command & Conquer', 'name equals'),
#  ("You Don't Know Jack", 'name equals'),
#  ('Rapala Pro Bass Fishing 2010', 'name equals'),
#  ('Road Rash: Jailbreak', 'name equals'),
#  ('Planet 51', 'name equals'),
#  ('Sherlock Holmes: The Mystery of the Mummy', 'name equals'),
#  ('Atari Anthology', 'name equals'),
#  ('Top Gear Rally', 'name equals'),
#  ('RR64: Ridge Racer 64', 'name equals'),
#  ('AKB1/48: Idol to Guam de Koishitara...', 'name equals'),
#  ('Iron Man 2', 'name equals'),
#  ('Fighting Vipers', 'name equals'),
#  ('Samurai Shodown', 'name equals'),
#  ('The Incredibles: Rise of the Underminer', 'name equals'),
#  ('The Chronicles of Narnia: Prince Caspian', 'name equals'),
#  ('Warriors Orochi 2 (JP sales)', 'name equals'),
#  ("Yu-Gi-Oh! 5D's Stardust Accelerator: World Championship 2009",
#   'name equals'),
#  ('Taiko no Tatsujin Wii: Dodon to 2 Yome!', 'name equals'),
#  ('WipeOut 3 The Game', 'name equals'),
#  ('Medarot: Kabuto / Kuwagata Version', 'name equals'),
#  ('Overlord', 'name equals'),
#  ('Mouse Trap', 'name equals'),
#  ('Pengo', 'name equals'),
#  ("Disney's Hercules / Disney's The Jungle Book: Groove Party / A Bug's Life",
#   'name equals'),
#  ('Minority Report: Everybody Runs', 'name equals'),
#  ('My Virtual Tutor: Reading Adventure First to Second Grade', 'name equals'),
#  ('From Russia With Love', 'name equals'),
#  ("Disney's Tarzan Untamed", 'name equals'),
#  ("Jikkyou Powerful Pro Yakuu '94", 'name equals'),
#  ('Ed, Edd n Eddy: The Mis-Edventures', 'name equals'),
#  ('Mario no Super Picross', 'name equals'),
#  ('Yu-Gi-Oh! The Eternal Duelist Soul (JP sales)', 'name equals'),
#  ("'98 Koshien", 'name equals'),
#  ('AKB1/48: Idol to Koishitara...', 'name equals'),
#  ('Armored Core 2: Another Age', 'name equals'),
#  ('The Wonderful 101', 'name equals'),
#  ('Densha De Go! 2', 'name equals'),
#  ("Rogue Galaxy: Director's Cut", 'name equals'),
#  ('UEFA Euro 2008 Austria-Switzerland', 'name equals'),
#  ('Boku no Natsuyasumi 2: Umi no Bouken Hen', 'name equals'),
#  ('Spider-Man: Web of Shadows', 'name equals'),
#  ('Monotaro Dentetsu 2010: Sengoku Ishin no Hero Daishuugou! no Maki',
#   'name equals'),
#  ('Six Flags Fun Park', 'name equals'),
#  ('Nicktoons: Unite!', 'name equals'),
#  ('E0: Enemy Zero', 'name equals'),
#  ('X-Men: The Official Game', 'name equals'),
#  ("James Patterson Women's Murder Club: Games of Passion", 'name equals'),
#  ('Mass Effect Trilogy', 'name equals'),
#  ('World Soccer Jikkyou Winning Eleven 2000: U-23 Medal heno Chousen',
#   'name equals'),
#  ('Grudge Warriors', 'name equals'),
#  ('Mobile Suit Gundam: Gundam vs. Gundam NEXT PLUS', 'name equals'),
#  ('Wheel of Fortune: 2nd Edition', 'name equals'),
#  ('Quake II', 'name equals'),
#  ('Sega Rally Championship 2', 'name equals'),
#  ('TERA', 'name equals'),
#  ('Scooby-Doo and the Cyber Chase', 'name equals'),
#  ("Dexter's Laboratory Deesaster Strikes", 'name equals'),
#  ('Jampack Spring 2004 (RP-T)', 'name equals'),
#  ('Star Wars Starfighter: Special Edition', 'name equals'),
#  ('Lord of the Rings: The Third Age', 'name equals'),
#  ('Double Pack: Finding Nemo / The Incredibles', 'name equals'),
#  ('Jimmy Neutron: Boy Genius', 'name equals'),
#  ('Harvest Moon: Grand Bazaar', 'name equals'),
#  ("Tom Clancy's HAWX 2", 'name equals'),
#  ('Kumamon Bomber: Puzzle de Kumamon Taisou', 'name equals'),
#  ('Style Lab: Makeover', 'name equals'),
#  ('JumpStart: Escape from Adventure Island', 'name equals'),
#  ('Taiko no Tatsujin DS: Dororon! Youkai Daikessen!!', 'name equals'),
#  ('The Fairly Odd Parents: Game Boy Advance Video Volume 2', 'name equals'),
#  ('Wolfenstein: The Old Blood', 'name equals'),
#  ("Army Men: Sarge's Heroes 2", 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 6', 'name equals'),
#  ('The Adventures of Jimmy Neutron Boy Genius: Jet Fusion', 'name equals'),
#  ('Ghost Trick: Phantom Detective', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 11', 'name equals'),
#  ('JGTC: All-Japan Grand Touring Car Championship', 'name equals'),
#  ('NiGHTS: Journey of Dreams', 'name equals'),
#  ('Avatar: The Last Airbender - The Burning Earth', 'name equals'),
#  ('Hot Wheels World Race', 'name equals'),
#  ("SpongeBob's Truth or Square (US sales)", 'name equals'),
#  ('Horsez', 'name equals'),
#  ('The X Files', 'name equals'),
#  ('25 to Life', 'name equals'),
#  ('The Legend of Spyro: The Eternal Night', 'name equals'),
#  ('Dai-2-Ji Super Robot Taisen Z: Hakai-hen', 'name equals'),
#  ('Neon Genesis Evangelion 2nd Impression', 'name equals'),
#  ('SEGA Classics Collection', 'name equals'),
#  ('The Smurfs', 'name equals'),
#  ('Call of Duty: Modern Warfare: Mobilized', 'name equals'),
#  ('TRON: Evolution', 'name equals'),
#  ('Def Jam Icon', 'name equals'),
#  ('Zone of the Enders HD Collection', 'name equals'),
#  ('999: Nine Hours, Nine Persons, Nine Doors', 'name equals'),
#  ('WipEout 64', 'name equals'),
#  ('Hunter: The Reckoning  Wayward', 'name equals'),
#  ('The Fairly Odd Parents: Game Boy Advance Video Volume 1', 'name equals'),
#  ('Wonder Project J: Kikai no Shonen Pino', 'name equals'),
#  ('Barnstorming', 'name equals'),
#  ('Bionicle', 'name equals'),
#  ('NiGHTS into dreams...', 'name equals'),
#  ('Dora the Explorer: Dora Puppy', 'name equals'),
#  ('Tetris Axis', 'name equals'),
#  ('NFL Blitz 20-03', 'name equals'),
#  ('Tongari Boushi to Mahou no Otana', 'name equals'),
#  ('SingStar Motown', 'name equals'),
#  ('Power Rangers: S.P.D.', 'name equals'),
#  ('Battlebots: Design & Destroy', 'name equals'),
#  ("Robert Ludlum's The Bourne Conspiracy", 'name equals'),
#  ('Super Breakout', 'name equals'),
#  ('Barbie: Groom and Glam Pups', 'name equals'),
#  ('Naruto: Gekito Ninja Taisen! 3', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 9', 'name equals'),
#  ('Army Men World War: Final Front', 'name equals'),
#  ('Super Robot Taisen OG: Original Generations', 'name equals'),
#  ('Jump Start Pet Rescue', 'name equals'),
#  ('Sin and Punishment: Star Successor', 'name equals'),
#  ('Gundam SEED: Federation vs. Z.A.F.T.', 'name equals'),
#  ('Family Fest Presents Circus Games', 'name equals'),
#  ('Independence Day', 'name equals'),
#  ('Densetsu no Stafi 2', 'name equals'),
#  ('The Godfather (US sales)', 'name equals'),
#  ('The Urbz: Sims in the City (all regions sales)', 'name equals'),
#  ('Van Helsing', 'name equals'),
#  ('The Thing', 'name equals'),
#  ('Teenage Mutant Ninja Turtles 2: Battle Nexus', 'name equals'),
#  ('Jampack Volume 13 (RP-M)', 'name equals'),
#  ('Major League Baseball 2K6', 'name equals'),
#  ('Karaoke Revolution', 'name equals'),
#  ('Jawbreaker', 'name equals'),
#  ('Mario Tennis Ultra Smash', 'name equals'),
#  ('Defender II', 'name equals'),
#  ('Samurai Warriors: Xtreme Legends', 'name equals'),
#  ('Final Fantasy Collection', 'name equals'),
#  ('SingStar Take That', 'name equals'),
#  ('Mobile Suit Gundam', 'name equals'),
#  ('Persona', 'name equals'),
#  ('Shin Megami Tensei: Persona 3', 'name equals'),
#  ('Bee Movie Game', 'name equals'),
#  ('Dance Dance Revolution: Hottest Party 3', 'name equals'),
#  ('Pokemon Puzzle League', 'name equals'),
#  ('Sphinx and the Cursed Mummy', 'name equals'),
#  ('World Soccer Winning Eleven 5 Final Evolution', 'name equals'),
#  ('Transformers: Revenge of the Fallen (Wii & PS2 Version)', 'name equals'),
#  ('Apocalypse', 'name equals'),
#  ('Rock Band Country Track Pack', 'name equals'),
#  ('Spider-Man: Shattered Dimensions', 'name equals'),
#  ('Phoenix', 'name equals'),
#  ('Star Wars Jedi Knight: Jedi Academy', 'name equals'),
#  ('TNA iMPACT!', 'name equals'),
#  ('NCAA Gamebreaker 99', 'name equals'),
#  ('Ghostbusters', 'name equals'),
#  ('Karaoke Revolution Presents American Idol Encore', 'name equals'),
#  ('The Powerpuff Girls: Relish Rampage', 'name equals'),
#  ('Petz Sports', 'name equals'),
#  ('Dragon Quest 25 Shuunen Kinin: Famicom & Super Famicom Dragon Quest I-II-III',
#   'name equals'),
#  ('ICO', 'name equals'),
#  ('WipEout', 'name equals'),
#  ('Dragon Age Origins: Awakening', 'name equals'),
#  ('The Godfather (JP sales)', 'name equals'),
#  ('Karate', 'name equals'),
#  ('Double Dragon', 'name equals'),
#  ('Fantavision', 'name equals'),
#  ('Ford Racing Off Road', 'name equals'),
#  ('Grand Prix', 'name equals'),
#  ('Final Fantasy Crystal Chronicles: Echoes of Time', 'name equals'),
#  ('Dynasty Warriors Gundam', 'name equals'),
#  ('Nickelodeon Team Umizoomi', 'name equals'),
#  ('Viva Pinata: Trouble in Paradise', 'name equals'),
#  ('Harvest Moon DS (US sales)', 'name equals'),
#  ('Bratz: The Movie', 'name equals'),
#  ('All-Star Baseball 99', 'name equals'),
#  ('OkamiDen', 'name equals'),
#  ('ECW Hardcore Revolution', 'name equals'),
#  ('Destroy All Humans! 2', 'name equals'),
#  ('Millipede', 'name equals'),
#  ('Yu-Gi-Oh! Forbidden Memories (JP sales)', 'name equals'),
#  ('Metal Gear Solid HD Edition', 'name equals'),
#  ('Scrabble 2007 Edition', 'name equals'),
#  ('Dead Space Extraction', 'name equals'),
#  ('Scene It? Lights Camera Action', 'name equals'),
#  ('Momotarou Dentetsu X: Kyuushuu-hen mo Arubai', 'name equals'),
#  ('Jake Power: Fireman', 'name equals'),
#  ('Spy Hunter 2', 'name equals'),
#  ('Sniper: Art of Victory', 'name equals'),
#  ('Alone in the Dark', 'name equals'),
#  ('WipEout Pulse', 'name equals'),
#  ('Backyard Baseball', 'name equals'),
#  ('J-League Pro Soccer Club wo Tsukurou! 2', 'name equals'),
#  ('Bakugan Battle Brawlers: Defenders of the Core', 'name equals'),
#  ('Pokemon Art Academy', 'name equals'),
#  ('Mobile Suit Gundam Seed Destiny: Rengou vs. Z.A.F.T. II Plus',
#   'name equals'),
#  ('Sonic Lost World', 'name equals'),
#  ('WWE Wrestlemania X8', 'name equals'),
#  ('Gauntlet', 'name equals'),
#  ('Nicktoons: Attack of the Toybots', 'name equals'),
#  ('RealSports Tennis', 'name equals'),
#  ('Fantastic 4', 'name equals'),
#  ('Shrek SuperSlam', 'name equals'),
#  ('SplashDown: Rides Gone Wild', 'name equals'),
#  ('Dreamworks Madagascar Kartz', 'name equals'),
#  ('Star Wars: Clone Wars', 'name equals'),
#  ('Dead or Alive Ultimate', 'name equals'),
#  ('Bleach: Soul Resurreccion', 'name equals'),
#  ('Boogie', 'name equals'),
#  ('Crash: Mind Over Mutant', 'name equals'),
#  ('Activision Anthology', 'name equals'),
#  ('Avatar: The Last Airbender', 'name equals'),
#  ('Atelier Rorona: Alchemist of Arland', 'name equals'),
#  ('Looney Tunes: Back in Action', 'name equals'),
#  ('The Adventures of Jimmy Neutron Boy Genius: Attack of the Twonkies',
#   'name equals'),
#  ('Hidden Mysteries: Titanic - Secrets of the Fateful Voyage', 'name equals'),
#  ('Capcom Classics Collection', 'name equals'),
#  ('The BIGS', 'name equals'),
#  ('Final Fantasy II Anniversary Edition', 'name equals'),
#  ('Test Drive Unlimited', 'name equals'),
#  ('Dai-4-Ji Super Robot Taisen S', 'name equals'),
#  ('SpongeBob SquarePants: Creature from the Krusty Krab', 'name equals'),
#  ('Monsters vs. Aliens', 'name equals'),
#  ('International Superstar Soccer 2000 (All region sales)', 'name equals'),
#  ('SpongeBob SquarePants: Lights, Camera, Pants!', 'name equals'),
#  ('Dynasty Warriors', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 10', 'name equals'),
#  ('Jam With the Band', 'name equals'),
#  ('Lords of the Fallen', 'name equals'),
#  ('StarCraft II: Legacy of the Void', 'name equals'),
#  ('HSX HyperSonic.Xtreme', 'name equals'),
#  ('Prince of Persia Trilogy', 'name equals'),
#  ('SSX On Tour', 'name equals'),
#  ('Kenkou Ouen Recipe 1000: DS Kondate Zenshuu', 'name equals'),
#  ('The Punisher', 'name equals'),
#  ('Tomb Raider: Legend', 'name equals'),
#  ("Cars Toon: Mater's Tall Tales", 'name equals'),
#  ('Rival Schools: United By Fate', 'name equals'),
#  ('Final Fantasy Explorers', 'name equals'),
#  ('Syphon Filter 3', 'name equals'),
#  ('Final Fantasy Chronicles', 'name equals'),
#  ('Go Diego Go! Safari Rescue', 'name equals'),
#  ('J-League Soccer: Prime Goal 2', 'name equals'),
#  ('Juiced', 'name equals'),
#  ('Littlest Pet Shop 3: Biggest Stars - Blue / Pink / Purple Team',
#   'name equals'),
#  ('Alice in Wonderland', 'name equals'),
#  ('Ty the Tasmanian Tiger 2: Bush Rescue', 'name equals'),
#  ('SingStar Dance', 'name equals'),
#  ('Sesame Street: Once Upon A Monster', 'name equals'),
#  ('Jampack Vol. 2', 'name equals'),
#  ('Gex 3: Deep Cover Gecko', 'name equals'),
#  ('MLB SlugFest 20-04', 'name equals'),
#  ('2 in 1 Combo Pack: Sonic Heroes / Super Monkey Ball Deluxe', 'name equals'),
#  ('SpongeBob SquarePants: Game Boy Advance Video Volume 2', 'name equals'),
#  ('Jampack Volume 11', 'name equals'),
#  ('Clock Tower', 'name equals'),
#  ('Sakura Taisen 2 - Kimi, Shinitamou Koto Nakare', 'name equals'),
#  ('Tales of Symphonia: Dawn of the New World', 'name equals'),
#  ('War of the Monsters', 'name equals'),
#  ('The Hobbit', 'name equals'),
#  ('Lego Star Wars: The Force Awakens', 'name equals'),
#  ("Mat Hoffman's Pro BMX", 'name equals'),
#  ('Over the Hedge', 'name equals'),
#  ('World Soccer Winning Eleven 7 International (JP version)', 'name equals'),
#  ('How to Train Your Dragon', 'name equals'),
#  ('Bratz: Rock Angelz', 'name equals'),
#  ('Terminator Salvation', 'name equals'),
#  ('Valkyria Chronicles II', 'name equals'),
#  ('Dragon Quest Characters: Torneko no Daibouken 3: Fushigi no Dungeon',
#   'name equals'),
#  ('Kidou Senshi Gundam: Extreme VS', 'name equals'),
#  ('Action Force', 'name equals'),
#  ('Ninokuni: Shikkoku no Madoushi', 'name equals'),
#  ("The Fairly Odd Parents: Breakin' Da Rules", 'name equals'),
#  ('Crash Tag Team Racing', 'name equals'),
#  ('Dance Dance Revolution Ultramix', 'name equals'),
#  ('System 3 presents Ferrari Challenge Trofeo Pirelli', 'name equals'),
#  ('Medarot 2: Kabuto / Kuwagata Version', 'name equals'),
#  ('Gekikuukan Pro Yakyuu: At the End of the Century 1999', 'name equals'),
#  ('SingStar Summer Party', 'name equals'),
#  ('American Idol', 'name equals'),
#  ('Are You Smarter than a 5th Grader? Make the Grade', 'name equals'),
#  ('Metro 2033', 'name equals'),
#  ('Super Robot Taisen F Kanketsuhen', 'name equals'),
#  ('Time Crisis: Razing Storm', 'name equals'),
#  ('Soccer Tsuku 2002: J-League Pro Soccer Club o Tsukurou!', 'name equals'),
#  ('The Amazing Spider-Man 2 (2014)', 'name equals'),
#  ('CrossworDS', 'name equals'),
#  ('Barbie Horse Adventures: Riding Camp', 'name equals'),
#  ('Secret Agent Clank(US sales)', 'name equals'),
#  ('F.E.A.R.', 'name equals'),
#  ('TMNT', 'name equals'),
#  ('Tatsunoko vs. Capcom: Ultimate All-Stars', 'name equals'),
#  ('Batman: Vengeance', 'name equals'),
#  ('Extermination', 'name equals'),
#  ('Yokai Sangokushi', 'name equals'),
#  ('Simple 1500 Series Vol. 73: The Invaders ~Space Invaders 1500~',
#   'name equals'),
#  ('The Activision Decathlon', 'name equals'),
#  ('Legends of WrestleMania', 'name equals'),
#  ('Shin Super Robot Taisen', 'name equals'),
#  ('Harry Potter and the Deathly Hallows - Part 1', 'name equals'),
#  ('Daytona USA', 'name equals'),
#  ('The Godfather (old US sales)', 'name equals'),
#  ('Soul Reaver 2', 'name equals'),
#  ('ZhuZhu Pets 2: Featuring The Wild Bunch', 'name equals'),
#  ('MX vs. ATV: Alive', 'name equals'),
#  ('God of War: Origins Collection', 'name equals'),
#  ('Rapala Tournament Fishing!', 'name equals'),
#  ('Soldier of Fortune: Gold Edition', 'name equals'),
#  ('Catz', 'name equals'),
#  ('Barbie Groovy Games', 'name equals'),
#  ("Dr. Seuss' The Cat in the Hat", 'name equals'),
#  ('Batman Begins', 'name equals'),
#  ('Final Fantasy IV: The Complete Collection', 'name equals'),
#  ('Backyard NFL Football', 'name equals'),
#  ("Cabela's Big Game Hunter 2005 Adventures", 'name equals'),
#  ('Harry Potter Collection', 'name equals'),
#  ('NHL Hitz 20-02', 'name equals'),
#  ('Ms. Pac-Man Maze Madness', 'name equals'),
#  ('The Incredible Hulk', 'name equals'),
#  ('Donkey Kong Jungle Climber', 'name equals'),
#  ('American Idol', 'name equals'),
#  ('Are You Smarter than a 5th Grader? Make the Grade', 'name equals'),
#  ('Metro 2033', 'name equals'),
#  ('Super Robot Taisen F Kanketsuhen', 'name equals'),
#  ('Time Crisis: Razing Storm', 'name equals'),
#  ('Soccer Tsuku 2002: J-League Pro Soccer Club o Tsukurou!', 'name equals'),
#  ('The Amazing Spider-Man 2 (2014)', 'name equals'),
#  ('CrossworDS', 'name equals'),
#  ('Barbie Horse Adventures: Riding Camp', 'name equals'),
#  ('Secret Agent Clank(US sales)', 'name equals'),
#  ('F.E.A.R.', 'name equals'),
#  ('TMNT', 'name equals'),
#  ('Tatsunoko vs. Capcom: Ultimate All-Stars', 'name equals'),
#  ('Batman: Vengeance', 'name equals'),
#  ('Extermination', 'name equals'),
#  ('Yokai Sangokushi', 'name equals'),
#  ('Simple 1500 Series Vol. 73: The Invaders ~Space Invaders 1500~',
#   'name equals'),
#  ('The Activision Decathlon', 'name equals'),
#  ('Legends of WrestleMania', 'name equals'),
#  ('Shin Super Robot Taisen', 'name equals'),
#  ('Harry Potter and the Deathly Hallows - Part 1', 'name equals'),
#  ('Daytona USA', 'name equals'),
#  ('The Godfather (old US sales)', 'name equals'),
#  ('Soul Reaver 2', 'name equals'),
#  ('ZhuZhu Pets 2: Featuring The Wild Bunch', 'name equals'),
#  ('MX vs. ATV: Alive', 'name equals'),
#  ('God of War: Origins Collection', 'name equals'),
#  ('Rapala Tournament Fishing!', 'name equals'),
#  ('Soldier of Fortune: Gold Edition', 'name equals'),
#  ('Catz', 'name equals'),
#  ('Barbie Groovy Games', 'name equals'),
#  ("Dr. Seuss' The Cat in the Hat", 'name equals'),
#  ('Batman Begins', 'name equals'),
#  ('Final Fantasy IV: The Complete Collection', 'name equals'),
#  ('Backyard NFL Football', 'name equals'),
#  ("Cabela's Big Game Hunter 2005 Adventures", 'name equals'),
#  ('Harry Potter Collection', 'name equals'),
#  ('NHL Hitz 20-02', 'name equals'),
#  ('Ms. Pac-Man Maze Madness', 'name equals'),
#  ('The Incredible Hulk', 'name equals'),
#  ('Donkey Kong Jungle Climber', 'name equals'),
#  ('Petz Sports', 'name equals'),
#  ('Dragon Quest 25 Shuunen Kinin: Famicom & Super Famicom Dragon Quest I-II-III',
#   'name equals'),
#  ('ICO', 'name equals'),
#  ('WipEout', 'name equals'),
#  ('Dragon Age Origins: Awakening', 'name equals'),
#  ('The Godfather (JP sales)', 'name equals'),
#  ('Karate', 'name equals'),
#  ('Double Dragon', 'name equals'),
#  ('Fantavision', 'name equals'),
#  ('Ford Racing Off Road', 'name equals'),
#  ('Grand Prix', 'name equals'),
#  ('Final Fantasy Crystal Chronicles: Echoes of Time', 'name equals'),
#  ('Dynasty Warriors Gundam', 'name equals'),
#  ('Nickelodeon Team Umizoomi', 'name equals'),
#  ('Viva Pinata: Trouble in Paradise', 'name equals'),
#  ('Harvest Moon DS (US sales)', 'name equals'),
#  ('Bratz: The Movie', 'name equals'),
#  ('All-Star Baseball 99', 'name equals'),
#  ('OkamiDen', 'name equals'),
#  ('ECW Hardcore Revolution', 'name equals'),
#  ('Destroy All Humans! 2', 'name equals'),
#  ('Millipede', 'name equals'),
#  ('Yu-Gi-Oh! Forbidden Memories (JP sales)', 'name equals'),
#  ('Metal Gear Solid HD Edition', 'name equals'),
#  ('Scrabble 2007 Edition', 'name equals'),
#  ('Dead Space Extraction', 'name equals'),
#  ('Scene It? Lights Camera Action', 'name equals'),
#  ('Momotarou Dentetsu X: Kyuushuu-hen mo Arubai', 'name equals'),
#  ('Jake Power: Fireman', 'name equals'),
#  ('Spy Hunter 2', 'name equals'),
#  ('Sniper: Art of Victory', 'name equals'),
#  ('Alone in the Dark', 'name equals'),
#  ('WipEout Pulse', 'name equals'),
#  ('Backyard Baseball', 'name equals'),
#  ('J-League Pro Soccer Club wo Tsukurou! 2', 'name equals'),
#  ('Bakugan Battle Brawlers: Defenders of the Core', 'name equals'),
#  ('Pokemon Art Academy', 'name equals'),
#  ('Mobile Suit Gundam Seed Destiny: Rengou vs. Z.A.F.T. II Plus',
#   'name equals'),
#  ('Sonic Lost World', 'name equals'),
#  ('WWE Wrestlemania X8', 'name equals'),
#  ('Gauntlet', 'name equals'),
#  ('Nicktoons: Attack of the Toybots', 'name equals'),
#  ('RealSports Tennis', 'name equals'),
#  ('Fantastic 4', 'name equals'),
#  ('Shrek SuperSlam', 'name equals'),
#  ('SplashDown: Rides Gone Wild', 'name equals'),
#  ('Dreamworks Madagascar Kartz', 'name equals'),
#  ('Star Wars: Clone Wars', 'name equals'),
#  ('Dead or Alive Ultimate', 'name equals'),
#  ('Bleach: Soul Resurreccion', 'name equals'),
#  ('Boogie', 'name equals'),
#  ('Crash: Mind Over Mutant', 'name equals'),
#  ('Activision Anthology', 'name equals'),
#  ('Avatar: The Last Airbender', 'name equals'),
#  ('Atelier Rorona: Alchemist of Arland', 'name equals'),
#  ('Looney Tunes: Back in Action', 'name equals'),
#  ('The Adventures of Jimmy Neutron Boy Genius: Attack of the Twonkies',
#   'name equals'),
#  ('Hidden Mysteries: Titanic - Secrets of the Fateful Voyage', 'name equals'),
#  ('Capcom Classics Collection', 'name equals'),
#  ('The BIGS', 'name equals'),
#  ('Final Fantasy II Anniversary Edition', 'name equals'),
#  ('Test Drive Unlimited', 'name equals'),
#  ('Dai-4-Ji Super Robot Taisen S', 'name equals'),
#  ('SpongeBob SquarePants: Creature from the Krusty Krab', 'name equals'),
#  ('Monsters vs. Aliens', 'name equals'),
#  ('International Superstar Soccer 2000 (All region sales)', 'name equals'),
#  ('SpongeBob SquarePants: Lights, Camera, Pants!', 'name equals'),
#  ('Dynasty Warriors', 'name equals'),
#  ('Jikkyou Powerful Pro Yakyuu 10', 'name equals'),
#  ('Jam With the Band', 'name equals'),
#  ('Lords of the Fallen', 'name equals'),
#  ('StarCraft II: Legacy of the Void', 'name equals'),
#  ('HSX HyperSonic.Xtreme', 'name equals'),
#  ('Prince of Persia Trilogy', 'name equals'),
#  ('SSX On Tour', 'name equals'),
#  ('Kenkou Ouen Recipe 1000: DS Kondate Zenshuu', 'name equals'),
#  ('The Punisher', 'name equals'),
#  ('Tomb Raider: Legend', 'name equals'),
#  ("Cars Toon: Mater's Tall Tales", 'name equals'),
#  ('Rival Schools: United By Fate', 'name equals'),
#  ('Final Fantasy Explorers', 'name equals'),
#  ('Syphon Filter 3', 'name equals'),
#  ('Final Fantasy Chronicles', 'name equals'),
#  ('Go Diego Go! Safari Rescue', 'name equals'),
#  ('J-League Soccer: Prime Goal 2', 'name equals'),
#  ('Juiced', 'name equals'),
#  ('Littlest Pet Shop 3: Biggest Stars - Blue / Pink / Purple Team',
#   'name equals'),
#  ('Alice in Wonderland', 'name equals'),
#  ('Ty the Tasmanian Tiger 2: Bush Rescue', 'name equals'),
#  ('SingStar Dance', 'name equals'),
#  ('Sesame Street: Once Upon A Monster', 'name equals'),
#  ('Jampack Vol. 2', 'name equals'),
#  ('Gex 3: Deep Cover Gecko', 'name equals'),
#  ('MLB SlugFest 20-04', 'name equals'),
#  ('2 in 1 Combo Pack: Sonic Heroes / Super Monkey Ball Deluxe', 'name equals'),
#  ('SpongeBob SquarePants: Game Boy Advance Video Volume 2', 'name equals'),
#  ('Jampack Volume 11', 'name equals'),
#  ('Clock Tower', 'name equals'),
#  ('Sakura Taisen 2 - Kimi, Shinitamou Koto Nakare', 'name equals'),
#  ('Tales of Symphonia: Dawn of the New World', 'name equals'),
#  ('War of the Monsters', 'name equals'),
#  ('The Hobbit', 'name equals'),
#  ('Lego Star Wars: The Force Awakens', 'name equals'),
#  ("Mat Hoffman's Pro BMX", 'name equals'),
#  ('Over the Hedge', 'name equals'),
#  ('World Soccer Winning Eleven 7 International (JP version)', 'name equals'),
#  ('How to Train Your Dragon', 'name equals'),
#  ('Bratz: Rock Angelz', 'name equals'),
#  ('Terminator Salvation', 'name equals'),
#  ('Valkyria Chronicles II', 'name equals'),
#  ('Dragon Quest Characters: Torneko no Daibouken 3: Fushigi no Dungeon',
#   'name equals'),
#  ('Kidou Senshi Gundam: Extreme VS', 'name equals'),
#  ('Action Force', 'name equals'),
#  ('Ninokuni: Shikkoku no Madoushi', 'name equals'),
#  ("The Fairly Odd Parents: Breakin' Da Rules", 'name equals'),
#  ('Crash Tag Team Racing', 'name equals'),
#  ('Dance Dance Revolution Ultramix', 'name equals'),
#  ('System 3 presents Ferrari Challenge Trofeo Pirelli', 'name equals'),
#  ('Medarot 2: Kabuto / Kuwagata Version', 'name equals'),
#  ('Gekikuukan Pro Yakyuu: At the End of the Century 1999', 'name equals'),
#  ('SingStar Summer Party', 'name equals'),
#  ('American Idol', 'name equals'),
#  ('Are You Smarter than a 5th Grader? Make the Grade', 'name equals'),
#  ('Metro 2033', 'name equals'),
#  ('Super Robot Taisen F Kanketsuhen', 'name equals'),
#  ('Time Crisis: Razing Storm', 'name equals'),
#  ('Soccer Tsuku 2002: J-League Pro Soccer Club o Tsukurou!', 'name equals'),
#  ('The Amazing Spider-Man 2 (2014)', 'name equals'),
#  ('CrossworDS', 'name equals'),
#  ('Barbie Horse Adventures: Riding Camp', 'name equals'),
#  ('Secret Agent Clank(US sales)', 'name equals'),
#  ('F.E.A.R.', 'name equals'),
#  ('TMNT', 'name equals'),
#  ('Tatsunoko vs. Capcom: Ultimate All-Stars', 'name equals'),
#  ('Batman: Vengeance', 'name equals'),
#  ('Extermination', 'name equals'),
#  ('Yokai Sangokushi', 'name equals'),
#  ('Simple 1500 Series Vol. 73: The Invaders ~Space Invaders 1500~',
#   'name equals'),
#  ('The Activision Decathlon', 'name equals'),
#  ('Legends of WrestleMania', 'name equals'),
#  ('Shin Super Robot Taisen', 'name equals'),
#  ('Harry Potter and the Deathly Hallows - Part 1', 'name equals'),
#  ('Daytona USA', 'name equals'),
#  ('The Godfather (old US sales)', 'name equals'),
#  ('Soul Reaver 2', 'name equals'),
#  ('ZhuZhu Pets 2: Featuring The Wild Bunch', 'name equals'),
#  ('MX vs. ATV: Alive', 'name equals'),
#  ('God of War: Origins Collection', 'name equals'),
#  ('Rapala Tournament Fishing!', 'name equals'),
#  ('Soldier of Fortune: Gold Edition', 'name equals'),
#  ('Catz', 'name equals'),
#  ('Barbie Groovy Games', 'name equals'),
#  ("Dr. Seuss' The Cat in the Hat", 'name equals'),
#  ('Batman Begins', 'name equals'),
#  ('Final Fantasy IV: The Complete Collection', 'name equals'),
#  ('Backyard NFL Football', 'name equals'),
#  ("Cabela's Big Game Hunter 2005 Adventures", 'name equals'),
#  ('Harry Potter Collection', 'name equals'),
#  ('NHL Hitz 20-02', 'name equals'),
#  ('Ms. Pac-Man Maze Madness', 'name equals'),
#  ('The Incredible Hulk', 'name equals'),
#  ('Donkey Kong Jungle Climber', 'name equals'),
#  ('XIII', 'name equals'),
#  ('Resident Evil Outbreak File #2', 'name equals'),
#  ('Bratz 4 Real', 'name equals'),
#  ('Super Bomberman', 'name equals'),
#  ('Wreckless: ThE YaKuza MisSiOns', 'name equals'),
#  ('FIFA World Cup Germany 2006', 'name equals'),
#  ('Jampack Summer 2002', 'name equals'),
#  ('Dora The Explorer: Dora Saves the Snow Princess', 'name equals'),
#  ('Dynasty Warriors 5: Xtreme Legends', 'name equals'),
#  ('Jillian Michaels Fitness Ultimatum 2010', 'name equals'),
#  ('NBA Hangtime', 'name equals'),
#  ('Defiance', 'name equals'),
#  ('Petz Wild Animals: Tigerz', 'name equals'),
#  ('Beyond The Beyond', 'name equals'),
#  ('Mobile Suit Gundam: Giren no Yabou- Zeon no Keifu', 'name equals'),
#  ('Blacksite: Area 51', 'name equals'),
#  ('Ratchet & Clank: Quest for Booty', 'name equals'),
#  ('Fire Emblem: Seisen no Keifu', 'name equals'),
#  ('Dragon Ball Z: Chou Saiya Densetsu', 'name equals'),
#  ('Mega Man Star Force 2: Zerker x Ninja / Saurian', 'name equals'),
#  ('Shrek 2: Beg for Mercy', 'name equals'),
#  ('Gex: Enter the Gecko', 'name equals'),
#  ('Tales of Phantasia', 'name equals'),
#  ('Unreal Tournament', 'name equals'),
#  ('World Cup 98', 'name equals'),
#  ('FIFA: Road to  World Cup 98', 'name equals'),
#  ('Transformers: War for Cybertron (XBox 360, PS3, & PC Versions)',
#   'name equals'),
#  ('Terminator 3: Rise of the Machines', 'name equals'),
#  ("Tom Clancy's HAWX", 'name equals'),
#  ('The Legend of Spyro: Dawn of the Dragon', 'name equals'),
#  ('Trivial Pursuit', 'name equals'),
#  ('Harvest Moon: Sunshine Islands', 'name equals'),
#  ('The Lord of the Rings: The Third Age', 'name equals'),
#  ('Tokimeki Memorial: Forever with You', 'name equals'),
#  ('Top Spin 3', 'name equals'),
#  ('Doom 3 BFG Edition', 'name equals'),
#  ('Final Fantasy Anniversary Edition', 'name equals'),
#  ('Mega Man Anniversary Collection', 'name equals'),
#  ('Game Party in Motion', 'name equals'),
#  ('Skate it', 'name equals'),
#  ('Go Diego Go! Great Dinosaur Rescue', 'name equals'),
#  ('Spelling Challenges and more!', 'name equals'),
#  ("Smurf: Rescue In Gargamel's Castle", 'name equals'),
#  ('2002 FIFA World Cup', 'name equals')]

# %%
def append_rows(rows: list | dict):
    pre_exisiting_titles = game_library.id.tolist()
    newly_added_titles = new_data_df.id.tolist()

    with open(new_data, 'a', encoding='utf-8') as csv_file:
        dict_writer = csv.DictWriter(csv_file, FIELDS)
        if isinstance(rows, dict):
            game_id = rows.get('id')
            # check that name isn't already in library
            if game_id not in pre_exisiting_titles and game_id not in newly_added_titles:
                print(rows[i].get('name'))
                dict_writer.writerow(rows)
            else:
                pass
        elif isinstance(rows, list):
            print('///')
            for i in range(len(rows)):
                if isinstance(rows[i], dict):
                    game_id = rows[i].get('id')
                    if game_id not in pre_exisiting_titles and game_id not in newly_added_titles:
                        print(rows[i].get('name'))
                        dict_writer.writerow(rows[i])

# %%
# write new rows to csv
append_rows(passes)
# Out:
# ///
# D1 Professional Drift Grand Prix Series
# Darius II
# RollerCoaster Tycoon 2: Triple Thrill Pack
# The Sims 2: Bon Voyage
# Divinity II: Flames of Vengeance
# Renegade Racers
# The King of Fighters: Maximum Impact - Maniax
# Wand of Fortune 2: Jikuu ni Shizumu Mokushiroku
# Combat Wings: The Great Battles of WWII
# Tank Beat
# Star Wars: Empire at War - Forces of Corruption
# Tube Slider
# Ghost Pirates of Vooju Island
# Pharaoh
# Pony Luv
# Vantage Master Portable
# Tropico 4: Modern Times
# Kensei: Sacred Fist
# Shanghai: True Valor
# Tokyo Xanadu eX+
# Vitamin Z Revolution
# Natalie Brooks: Mystery at Hillcrest High
# Treasure Chase
# RayCrisis: Series Termination
# Brandish: The Dark Revenant
# Samurai Shodown V
# Homeworld
# Invizimals: The Lost Kingdom
# Veggy World
# Doki Majo Plus
# Eureka Seven Vol. 2: The New Vision
# Motto! SoniComi
# Saint
# Steal Princess
# Legend: Hand of God
# Umineko no Naku Koro ni: Majo to Suiri no Rinbukyoku
# Dance! It's Your Stage
# Pebble Beach Golf Links
# The Lord of the Rings Online: Mines of Moria
# War Leaders: Clash of Nations
# Disney Sports Football
# Oil Rush
# Onechanbara Special
# Polar Bowler
# Chicago Enforcer
# Joker no Kuni no Alice: Wonderful Wonder World
# Cross Treasures
# Ruff Trigger: The Vanocore Conspiracy
# Silent Bomber
# TalkMan
# Elminage Gothic: Ulm Zakir to Yami no Gishiki
# Crayon Shin-Chan: Uchuu de Achoo!? Yuujou no Oba-Karate!!
# Invizimals: The Resistance
# Mushishi: Amefuru Sato
# Arcana Famiglia: Vascello Phantasma no Majutsushi
# ESPN MLS ExtraTime 2002
# Vitamin R
# Maximum Racing: Crash Car Racer
# Gakuen K: Wonderful School Days
# RollerCoaster Tycoon World
# Pastel Chime Continue
# Trapped Dead
# Super Fruit Fall
# Net High
# Kokoro Connect: Yochi Random
# Tenkai Knights: Brave Battle
# Mount & Blade: Warband
# Nervous Brickdown
# Legend of Kay Anniversary
# Spanish for Everyone!
# Battle Princess of Arcadias
# Angelique Retour
# Car Battler Joe
# Dino Dini's Kick Off Revival
# Atlantic Quest
# Tycoon City: New York
# Virtua Pro Football
# Adidas Power Soccer 98
# Natsuiro High School: Seishun Hakusho
# Kazoku Keikaku
# Rainbow Islands Revolution
# Virtual Kasparov
# Commandos 3: Destination Berlin
# Army Rescue
# Azada
# Zettai Meikyuu Grimm: Nanatsu no Kagi to Rakuen no Otome
# Hogs of War
# Point Blank 3
# Uru: Ages Beyond Myst
# Elvandia Story
# Puzzle Star Sweep
# Battle Spirits: Kiseki no Hasha
# X-Plane 10 Global
# The Cheetah Girls
# Rozen Maiden: Duellwalzer
# Winter Blast: 9 Snow & Ice Games
# The Talos Principle
# The Crow: City of Angels
# Broken Sword: The Sleeping Dragon
# Reversal Challenge
# Wild West Shootout
# Miyako
# Garfield's Nightmare
# Earth Seeker
# Barbie as the Princess and the Pauper
# Blood Bowl: Legendary Edition
# Pirates of the Burning Sea
# Mary King's Riding School 2
# Entaku no Seito: The Eternal Legend
# WorldShift
# 7 Roses: A Darkness Rises
# My Hero: Doctor
# Bomberman 2
# Peggle Nights
# Puzzle Guzzle
# Ketsui: Kizuna Jigoku Tachi Extra
# Aqua Panic!
# Kong: The Animated Series
# Agatha Christie: Death on the Nile
# Koisuru Otome to Shugo no Tate Portable
# Iridium Runners
# Tiny Toon Adventures: Wacky Stackers
# Emergency Mayhem
# Rising Zan: The Samurai Gunman
# Ultimate Puzzle Games
# Elminage II: Sousei no Megami to Unmei no Daichi
# Blazing Souls
# PDC World Championship Darts 2009
# Tail of the Sun
# Space Channel 5: Ulala's Cosmic Attack
# Airline Tycoon
# Virtua Quest
# Bejeweled Blitz
# Ozzy & Drix
# Barnyard Blast: Swine of the Night
# Castle Shikigami 2
# Pulse Racer
# Unreal Tournament 2004
# The Longest Journey
# Eyeshield 21: Portable Edition
# Stronghold Legends
# Winning Post 8 2016
# Golden Nugget Casino DS
# Machi-ing Maker 4
# Ketsui Death Label
# Prince of Stride
# SD Gundam Force
# Mechanic Master 2
# Cabbage Patch Kids: The Patch Puppy Rescue
# Pirates: Legend of the Black Buccaneer
# Post Mortem
# Amagoushi no Yakata
# Aedis Eclipse: Generation of Chaos
# Franklin: A Birthday Surprise
# Digimon Rumble Arena
# Vitamin X Evolution Plus
# Disciples III: Renaissance
# Nano Diver
# Elkrone no Atelier: Dear for Otomate
# DJ Star
# Top Gear RPM Tuning
# Cookie & Cream
# Memories Off: Yubikiri no Kioku
# Football Manager 2007
# Hurry Up Hedgehog!
# Hands On! Tangrams
# Discworld II: Mortality Bytes!
# One Piece Mansion
# Soul Eater: Monotone Princess
# Still Life 2
# Clock Zero: Shuuen no Ichibyou - ExTime
# Root Infinity Rexx
# Army Men: Major Malfunction
# Big Bass Fishing
# Reine des Fleurs
# Densha de Go! Shinkansen EX: Sanyou Shinkansen-hen
# Irritating Stick
# Kaleidoeve
# Simple 2000 Series Vol. 105: The Maid Fuku to Kikanjuu
# Pro Rally
# Kimi ni Todoke: Sodateru Omoi
# Zombie Hunters 2
# Custom Drive
# Ferrari: The Race Experience
# Achtung Panzer: Kharkov 1943
# Platypus
# Command & Conquer 4: Tiberian Twilight
# Farm Frenzy
# A Vampyre Story
# Phoenix Wright: Ace Attorney Trilogy
# LifeSigns: Surgical Unit
# I Love Horses: Rider's Paradise
# Zoey 101: Field Trip Fiasco
# Psychedelica of the Black Butterfly
# Assault Suit Leynos
# Elven Legacy
# Jet Impulse
# Shin Hisui no Shizuku: Hiiro no Kakera 2 Portable
# Pillars of Eternity
# Storm Lover Kai!!
# Race Driver: Create & Race
# Iron Soldier 3
# Storm Lover 2nd V
# Technic Beat
# Farming Simulator 2014
# Football Manager Live
# Black Cat
# Red Stone DS: Akaki Ishi ni Michibikareshi Monotachi
# Neverwinter Nights 2: Mask of the Betrayer
# Wand of Fortune Portable
# My Little Baby
# Super Robot Taisen XO
# Mortal Kombat: Tournament Edition
# Empire Deluxe
# Paranormal Pursuit: The Gifted One
# Hitotsu Tobashi Renai V
# Mystery Legends: Beauty and the Beast
# Jewel Quest II
# K-1 Grand Prix
# Legoland
# Caladrius
# Bunmei Kaika: Aoiza Ibunroku Saien
# Family Jockey
# Builder's Block
# Doraemon Wii: Himitsu Douguou Ketteisen!
# Death Connection Portable
# Duel Masters: Shadow of the Code
# Natsuzora no Monologue
# S.Y.K: Shinsetsu Saiyuuki Portable
# Grand Prix Legends
# Akatsuki no Amaneka to Aoi Kyojin
# Real Crimes: The Unicorn Killer
# Aladdin Magic Racer
# Agatha Christie: Peril at End House
# Dengeki Gakuen RPG: Cross of Venus Special
# DJ Max Technika Tune
# Crossroad Crisis
# Karnaaj Rally
# Dramatical Murder Re:code
# Scarlett: Nichijou no Kyoukaisen
# Mini Desktop Racing
# Neo Angelique Special
# Outdoors Unleashed: Africa 3D
# Planet Monsters
# Woody Woodpecker in Crazy Castle 5

# %%
# preview new rows
new_data_ = pd.read_csv(new_data)
new_data_df = pd.DataFrame(new_data_)
new_data_df
# Out:
#          id  release_dates                                       name  \
# 0       121         2011.0                                  Minecraft
# 1    135400         2018.0                                  Minecraft
# 2    119388         2023.0  The Legend of Zelda: Tears of the Kingdom
# 3      2744         2006.0                          Big Brain Academy
# 4    119295         2020.0                 Microsoft Flight Simulator
# ..      ...            ...                                        ...
# 767    5007         2005.0                        Mini Desktop Racing
# 768  221225         2008.0                      Neo Angelique Special
# 769   23671         2012.0              Outdoors Unleashed: Africa 3D
# 770   49359         2002.0                            Planet Monsters
# 771    8012         2004.0         Woody Woodpecker in Crazy Castle 5
#
#           category                                      slug  \
# 0        main_game                                 minecraft
# 1             port                              minecraft--1
# 2        main_game  the-legend-of-zelda-tears-of-the-kingdom
# 3        main_game                         big-brain-academy
# 4        main_game                microsoft-flight-simulator
# ..             ...                                       ...
# 767      main_game                       mini-desktop-racing
# 768  expanded_game                     neo-angelique-special
# 769      main_game              outdoors-unleashed-africa-3d
# 770      main_game                           planet-monsters
# 771      main_game        woody-woodpecker-in-crazy-castle-5
#
#                                              platforms  \
# 0           ['Linux', 'PC (Microsoft Windows)', 'Mac']
# 1    ['PC (Microsoft Windows)', 'Android', 'iOS', '...
# 2                                  ['Nintendo Switch']
# 3                             ['Nintendo DS', 'Wii U']
# 4    ['PC (Microsoft Windows)', 'Xbox One', 'Xbox S...
# ..                                                 ...
# 767  ['Wii', 'PC (Microsoft Windows)', 'PlayStation...
# 768                           ['PlayStation Portable']
# 769                                   ['Nintendo 3DS']
# 770                               ['Game Boy Advance']
# 771                               ['Game Boy Advance']
#
#                                     genres  \
# 0               ['Simulator', 'Adventure']
# 1               ['Simulator', 'Adventure']
# 2      ['Role-playing (RPG)', 'Adventure']
# 3                               ['Puzzle']
# 4                            ['Simulator']
# ..                                     ...
# 767                             ['Racing']
# 768                       ['Visual Novel']
# 769  ['Shooter', 'Simulator', 'Adventure']
# 770                             ['Puzzle']
# 771                 ['Platform', 'Puzzle']
#
#                                                   tags  \
# 0    ['17', '21', '33', '35', '38', '268435469', '2...
# 1    ['1', '17', '21', '33', '35', '38', '41', '268...
# 2    ['1', '17', '18', '38', '268435468', '26843548...
# 3    ['1', '34', '268435465', '536871186', '5368718...
# 4        ['32', '268435469', '536870968', '536873753']
# ..                                                 ...
# 767                                      ['268435466']
# 768  ['17', '31', '44', '268435490', '536871874', '...
# 769  ['1', '268435461', '268435469', '268435487', '...
# 770                                 ['1', '268435465']
# 771  ['1', '268435464', '268435465', '536872192', '...
#
#                                            age_ratings     rating  \
# 0    ['E10', 'Seven', 'CERO_A', 'USK_6', 'CLASS_IND...  84.545279
# 1    ['Seven', 'E10', 'CERO_A', 'USK_6', 'GRAC_Twel...  79.003788
# 2    ['CERO_B', 'GRAC_Twelve', 'CLASS_IND_Ten', 'E1...  96.989901
# 3                             ['E', 'Three', 'CERO_A']  57.981056
# 4                             ['E', 'Three', 'CERO_A']  93.519402
# ..                                                 ...        ...
# 767                                              ['E']        NaN
# 768                                         ['CERO_B']        NaN
# 769                         ['Sixteen', 'T', 'CERO_B']        NaN
# 770                                              ['E']        NaN
# 771                                              ['E']        NaN
#
#      rating_count                                      similar_games  \
# 0            1527  ['The Elder Scrolls V: Skyrim', 'Dishonored', ...
# 1              66  ['Life is Feudal: Your Own', 'Rising World', '...
# 2             129  ['Cyberpunk 2077', 'Borderlands 3', 'Immortal:...
# 3               8  ['Toby: The Secret Mine', 'Forgotton Anne', "D...
# 4              52  ['House Flipper', 'Cooking Simulator', "Jet de...
# ..            ...                                                ...
# 767             0  ['Rise: Race the Future', 'LA Street Racing', ...
# 768             0  ["Your Memories Off: Girl's Style", 'Angelique...
# 769             0  ['Star Control: Origins', 'Survivalist', 'Chil...
# 770             0  ['Digging Jim', 'Toby: The Secret Mine', "Don'...
# 771             0  ['Toby: The Secret Mine', 'Forgotton Anne', "D...
#
#                                                 themes  \
# 0    ['Fantasy', 'Survival', 'Sandbox', 'Kids', 'Op...
# 1    ['Action', 'Fantasy', 'Survival', 'Sandbox', '...
# 2    ['Action', 'Fantasy', 'Science fiction', 'Open...
# 3                            ['Action', 'Educational']
# 4                                      ['Non-fiction']
# ..                                                 ...
# 767                                                NaN
# 768                    ['Fantasy', 'Drama', 'Romance']
# 769                                         ['Action']
# 770                                         ['Action']
# 771                                         ['Action']
#
#                                                summary  \
# 0    Minecraft focuses on allowing the player to ex...
# 1    Minecraft focuses on allowing the player to ex...
# 2    The Legend of Zelda: Tears of the Kingdom is t...
# 3    Big Brain Academy features 15 activities that ...
# 4    Microsoft Flight Simulator is the next generat...
# ..                                                 ...
# 767  Mini Desktop Racing lets you loose with a craz...
# 768  Fully voiced and added omake events for the ch...
# 769  A downloadable game for 3DS in which you shoot...
# 770  There is only one rule with this game - Be the...
# 771  One day Mother Nature asks for Woody Woodpecke...
#
#                                     involved_companies
# 0                                   ['Mojang Studios']
# 1                                   ['Mojang Studios']
# 2    ['Nintendo EPD Production Group No. 3', 'Monol...
# 3    ['Nintendo EAD Software Development Group No.4...
# 4                ['Xbox Game Studios', 'Asobo Studio']
# ..                                                 ...
# 767  ['Data Design Interactive', 'Metro 3D', 'Consp...
# 768                                           ['Koei']
# 769                                          ['Teyon']
# 770                                                NaN
# 771                  ['Kemco', 'Tantalus Interactive']
#
# [772 rows x 15 columns]

# %% [markdown]
# Based on our filtering, this round of querying only returned 800 out of roughly 11,500 titles. This is because we were only allowing titles that were an exact match (search_type = 'name equals') to those in our original dataset. Based on prior analysis and testing, we have reason to believe many of the titles that did not pass do match those in our original dataset, but just may have slightly different formatting in their titles.
# There is also the possibility that a subset of the titles that did not pass did so because their entries in IGDB lack any data for the fields we need for training. There's not much that can be done about these, unless we consult other data sources, but that would host its own set of difficulties that may not be worth our time.
#
# The next step is to conduct another round of queries on the failed titles from this round, but with the next search_type, 'search'.
# The behavior of 'search' is not entirely clear, and may cause issues in our pipeline, so we must be careful and validate the results after each batch of chunks.

# %%
# get list of failed titles to retry
failed_titles = [i[0] for i in fails]
# failed_titles
# chunk the new list
failed_chunks = list(chunk(failed_titles, 100))
#
failed_chunks[0]
# Out:
# ('NBA',
#  "Pro Yakyuu Greatest Nine '97",
#  'Dorabase DS: Dramatic Stadium',
#  'EVE: burst error',
#  "Backyard NFL Football '09",
#  'Big League Sports',
#  "Magician's Quest: Town of Magic",
#  'Momotarou Dentetsu 16',
#  'Robotech: The Macross Saga',
#  'Yu Yu Hakusho: Dark Tournament',
#  'Gekijouban Macross F: Itsuwarino Utahime - Hybrid Pack',
#  'World Poker Tour',
#  'GRID Autosport',
#  'Ghostbusters II',
#  'RealSports Baseball',
#  'Quake III: Revolution',
#  'Pac-Man World 3',
#  'Naruto: Clash of Ninja (JP sales)',
#  'NOëL: NOT DiGITAL',
#  'Transformer: Rise of the Dark Spark',
#  'Dragon Ball Z Hyper Dimension',
#  'Maximo vs Army of Zin',
#  "The Fairly OddParents: Breakin' Da Rules",
#  'Namco Museum Megamix',
#  'Valkyria Chronicles III: Unrecorded Chronicles',
#  "Cruis'n Exotica",
#  "The King of Fighters '96",
#  'WRC: FIA World Rally Championship',
#  'Famicom Mini: Ganbare Goemon! Karakuri Douchuu',
#  'J-League Winning Eleven 10 + Europa League 06-07',
#  'Tales of Phantasia: Narikiri Dungeon X',
#  'JSRF: Jet Set Radio Future',
#  'The Last Airbender',
#  'StokEd',
#  'ESPN Winter X Games: Snowboarding 2002',
#  'I Spy: Castle',
#  'Shin Megami Tensei: Persona 3 (jp sales)',
#  'Barbie Fashion Show: An Eye for Style',
#  'Heisei Kyouiku linkai DS',
#  'SpongeBob SquarePants: Game Boy Advance Video Volume 3',
#  'BeyBlade VForce: Super Tournament Battle',
#  'Little Battlers eXperience: Baku Boost',
#  'Jikkyou Powerful Pro Yakyuu 2012',
#  'Attack on Titan (KOEI)',
#  'Beyblade G-Revolution',
#  'SD Gundam GNext',
#  'Backyard NFL Football 2006',
#  'Sloane to MacHale no Nazo no Monogatari',
#  'Dark Messiah of Might and Magic Elements',
#  'Just Dance 2: Extra Songs',
#  'International Superstar Soccer 2000',
#  'CandyLand / Chutes & Ladders / Memory',
#  'The Bible Game',
#  "Drift King Shutokou Battle '94",
#  'PBR: Out of the Chute',
#  'The King of Fighters Collection: The Orochi Saga',
#  'Jikkyou Powerful Pro Yakyuu 10 Chou Ketteiban: 2003 Memorial',
#  'Samurai Spirits (CD)',
#  'Rocket Power: Zero Gravity Zone',
#  'Le Mans 24 Hours',
#  'Captain America: Super Soldier',
#  'Mobile Suit Gundam Side Story II: Aoi o Uketsugu Mono',
#  'Kurohyou 2: Ryu ga Gotoku Ashura Hen',
#  'Taiko no Tatsujin: Waku Waku Anime Matsuri',
#  'Ogre Battle Saga Episode Five: The March of the Black Queen',
#  "Ni Hao, Kai-lan: New Year's Celebration",
#  'The Legend of Heroes VII: The Trail of Blue',
#  'CSI: Unsolved!',
#  'Roadsters 99',
#  'Magical Tetris Challenge',
#  "Disney's Tarzan",
#  'San Francisco Rush 2049',
#  'Magical ZhuZhu Princess: Carriages & Castles',
#  'Total War: Shogun 2 - Fall of the Samurai',
#  'Pro Yaky? Spirits 2013',
#  'We Wish You A Merry Christmas',
#  'BioShock The Collection',
#  'Namco Museum Vol.4',
#  'Teenage Mutant Ninja Turtles 3: Mutant Nightmare',
#  'Pro Yaky? Spirits 2012',
#  'Puzzle & Dragons X: God Chapter / Dragon Chapter',
#  "Sid Meier's Pirates!",
#  'Bust-A-Move 2 Arcade Edition',
#  'Tetris Worlds (Online Edition)',
#  'Go Play: Lumberjacks',
#  'Puzzle Challenge: Crosswords and More!',
#  'Backyard Hockey',
#  'The Fairly Odd Parents: Enter the Cleft',
#  'DS Kageyama Method: Dennou Hanpuku - Masu x Masu Hyaku Masu Keisan',
#  'Family Guy',
#  'Mega Man Legacy Collection',
#  'Big Mutha Truckers 2',
#  'The Great Escape',
#  "Dexter's Lab Chess Challenge",
#  'Nostalgia',
#  'The Rise of the Argonauts',
#  'ESA Foundation Compilation',
#  'Dragon Ball Z: Idainaru Dragon Ball Densetsu',
#  'Ni Hao, Kai-lan: Super Game Day',
#  'Petz Pony: Beauty Pageant')

# %%
for c in failed_chunks[0:1]:
    for i, j in enumerate(c):
        title = j
        search_type = 'search'
        query = format_query(title, search_type=search_type)
        response = post_request(query, twitch_client_id, access_token)
        result = validate_response(response, title, exact_matches_only=False)

        if isinstance(result, dict):
            print(result.json())
            print('\n\n')
            # # for some reason some of these don't have release_dates handling that here is easier
            # if result.get('release_dates'):
            #     if result.get('id') not in game_library.id.tolist():
            #         if display:
            #             print(f"PASS: {result.get('name')}")
            #         parsed_response = parse_response(result)
            #         passes.append(parsed_response)
            #     else:
            #         discards.append(result)
            # elif not result.get('release_dates'):
            #     discards.append(result)

        elif isinstance(result, list):
            for r in result:
                print(r.json())
                print('\n\n')
            # for r in result:
            #     resp = r.json()
            #     print(resp)
            #     if resp.get('release_dates'):
            #         if resp.get('id') not in game_library.id.tolist():
            #             if display:
            #                 print(f"PASS: {resp.get('name')}")
            #             parsed_response = parsed_response(resp)
            #             passes.append(resp)
            #         else:
            #             discards.append(resp)
            #     elif not r.get('release_dates'):
            #         discards.append(resp)
        else:
            fails.append((title, search_type))
if display:
    print(f"{len(passes)}, {len(fails)}, {len(discards)}")
# Out:
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# [{'id': 45573, 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 102777, 'company': {'id': 1, 'name': 'Electronic Arts'}}], 'name': 'NBA Showdown', 'platforms': [{'id': 19, 'name': 'Super Nintendo Entertainment System'}, {'id': 29, 'name': 'Sega Mega Drive/Genesis'}], 'release_dates': [{'id': 201522, 'y': 1994}, {'id': 201523, 'y': 1993}, {'id': 201524, 'y': 1994}], 'similar_games': [{'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 46284, 'name': 'Bulls Versus Blazers and the NBA Playoffs'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 96209, 'name': 'FIFA 19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showdown', 'summary': "The final entry in Electronic Arts' basketball series based on the old NBA playoffs engine before the NBA Live series took over.\nFor the first time, the game features all 27 NBA teams from the 1993-1994 season. You can now play a full season with 82 games in addition to playoffs and exhibition games.", 'tags': [32, 268435470, 536870970, 536875125, 536877457, 536877461, 536877466], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 3554, 'age_ratings': [{'id': 1678, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 214056, 'company': {'id': 566, 'name': 'Midway'}}, {'id': 214057, 'company': {'id': 425, 'name': 'Eurocom Entertainment Software'}}], 'name': 'NBA Showtime: NBA on NBC', 'platforms': [{'id': 4, 'name': 'Nintendo 64'}, {'id': 7, 'name': 'PlayStation'}, {'id': 23, 'name': 'Dreamcast'}, {'id': 52, 'name': 'Arcade'}], 'release_dates': [{'id': 8023, 'y': 1999}, {'id': 8024, 'y': 1999}, {'id': 8025, 'y': 1999}, {'id': 8026, 'y': 1999}], 'similar_games': [{'id': 40205, 'name': 'NBA Jam Extreme'}, {'id': 43718, 'name': 'NBA In the Zone 2000'}, {'id': 45573, 'name': 'NBA Showdown'}, {'id': 46067, 'name': 'Bulls vs Lakers and the NBA Playoffs'}, {'id': 49904, 'name': 'NBA 3 on 3 Featuring Kobe Bryant'}, {'id': 72053, 'name': "NBA in the Zone '99"}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 103275, 'name': 'NBA Live 19'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-showtime-nba-on-nbc', 'summary': 'NBA Showtime is an arcade-style basketball game from the developers of NBA Jam and NBA Hangtime.', 'tags': [32, 268435470, 536870970, 536875615, 536876973, 536877457, 536877461, 536877466, 536880491, 536884031], 'themes': [{'id': 32, 'name': 'Non-fiction'}]}, {'id': 8832, 'age_ratings': [{'id': 28179, 'rating': 8}], 'category': 0, 'genres': [{'id': 13, 'name': 'Simulator'}, {'id': 14, 'name': 'Sport'}], 'involved_companies': [{'id': 21723, 'company': {'id': 694, 'name': 'Visual Concepts'}}, {'id': 99860, 'company': {'id': 1272, 'name': 'Sega Sports R&D'}}], 'name': 'NBA 2K', 'platforms': [{'id': 23, 'name': 'Dreamcast'}], 'release_dates': [{'id': 26387, 'y': 2000}, {'id': 26388, 'y': 1999}, {'id': 26389, 'y': 1999}], 'similar_games': [{'id': 4643, 'name': 'World Soccer: Winning Eleven 6 International'}, {'id': 28836, 'name': 'NBA 2K1'}, {'id': 38967, 'name': 'Cooking Simulator'}, {'id': 47358, 'name': 'NBA Inside Drive 2003'}, {'id': 78511, 'name': 'Forza Motorsport'}, {'id': 102805, 'name': 'WWE 2K19'}, {'id': 103218, 'name': 'NBA 2K19'}, {'id': 114285, 'name': 'NBA 2K20'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}], 'slug': 'nba-2k', 'summary': 'NBA 2K (also known as NBA2K or Sega Sports: NBA 2000) is the first installment of the NBA 2K series. It was published by Sega Sports and developed by Visual Concepts. The cover features Allen Iverson of the Philadelphia 76ers', 'tags': [32, 268435469, 268435470, 536870970, 536871721, 536872352, 536875265, 536875525, 536875562, 536875615, 536875941, 536876190, 536880441, ...
#
#
#
# ...
#
#
#
# [{'id': 206012, 'age_ratings': [{'id': 75689, 'rating': 8}], 'category': 0, 'involved_companies': [{'id': 176282, 'company': {'id': 603, 'name': 'Humongous Entertainment'}}, {'id': 176283, 'company': {'id': 2845, 'name': 'Mistic Software'}}, {'id': 176284, 'company': {'id': 82, 'name': 'Atari'}}, {'id': 176285, 'company': {'id': 33812, 'name': 'Infogames'}}], 'name': 'Backyard Hockey', 'platforms': [{'id': 6, 'name': 'PC (Microsoft Windows)'}], 'release_dates': [{'id': 367840, 'y': 2002}], 'slug': 'backyard-hockey--2'}, {'id': 122753, 'age_ratings': [{'id': 72536, 'rating': 8}], 'category': 0, 'name': 'Backyard Hockey', 'slug': 'backyard-hockey--1'}, {'id': 49244, 'age_ratings': [{'id': 72537, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'name': 'Backyard Hockey', 'platforms': [{'id': 24, 'name': 'Game Boy Advance'}], 'release_dates': [{'id': 95795, 'y': 2003}], 'similar_games': [{'id': 4048, 'name': 'NHL Hitz Pro'}, {'id': 5071, 'name': 'NHL Slapshot'}, {'id': 5826, 'name': 'ESPN NHL 2K5'}, {'id': 8841, 'name': 'ESPN NHL Hockey'}, {'id': 27062, 'name': 'NHL Hockey'}, {'id': 44993, 'name': 'Backyard Soccer'}, {'id': 46638, 'name': 'Backyard Hockey 2005'}, {'id': 57656, 'name': 'Ice Hockey'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 116353, 'name': 'Real Football 2019'}], 'slug': 'backyard-hockey', 'summary': "Skate, shoot and score with the Backyard Kids and kid versions of the hottest NHL? pros! You can control all of the action in this hockey favorite. Build your own talented team, choose an awesome rink and zoom down the ice! With zany power-ups and that one-of-a-kind Backyard Sports excitement, Backyard Hockey provides fun, speedy, end-to-end action. Now that it's on the Game Boy Advance system, you can hit the game-winning slapshot anywhere", 'tags': [268435470, 536870956, 536871368, 536871745, 536872475, 536873064, 536873274, 536875257, 536875735, 536875868, 536875941, 536877938, 536881516]}, {'id': 46638, 'age_ratings': [{'id': 61857, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'name': 'Backyard Hockey 2005', 'platforms': [{'id': 6, 'name': 'PC (Microsoft Windows)'}], 'release_dates': [{'id': 97961, 'y': 2004}], 'similar_games': [{'id': 3562, 'name': "NHL Blades of Steel '99"}, {'id': 72711, 'name': 'Backyard Soccer 2004'}, {'id': 109606, 'name': 'Pro Yakyuu Spirits 2019'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}, {'id': 116349, 'name': 'Real Football 2014'}, {'id': 116350, 'name': 'Real Football 2015'}, {'id': 116351, 'name': 'Real Football 2017'}, {'id': 116352, 'name': 'Real Football 2018'}, {'id': 116353, 'name': 'Real Football 2019'}], 'slug': 'backyard-hockey-2005', 'summary': 'Backyard Hockey returns for 2005 with a new lineup of NHL kids and new 3d gameplay. This year you can draft from 30 backyard kids and 14 NHL Stars. You can also create custom players that improve with experience. All 30 NHL teams are included along with favorite backyard teams from earlier editions. \n \nThe game features three modes: Quick play, Season Play and Exhibition. The games can take place in nine different rinks including Sharkbelly Shores, Ice Castle Arcade and street hockey areas. As you progress you can unlock secret NHL players, rinks, bonus music etc. \n \nThe game keeps stats of players and teams throughout the season. Also a bonus Air Hockey Mini-Game is included.', 'tags': [268435470, 536871368, 536871745, 536875562, 536875735, 536884022]}]
#
#
#
# [{'id': 206012, 'age_ratings': [{'id': 75689, 'rating': 8}], 'category': 0, 'involved_companies': [{'id': 176282, 'company': {'id': 603, 'name': 'Humongous Entertainment'}}, {'id': 176283, 'company': {'id': 2845, 'name': 'Mistic Software'}}, {'id': 176284, 'company': {'id': 82, 'name': 'Atari'}}, {'id': 176285, 'company': {'id': 33812, 'name': 'Infogames'}}], 'name': 'Backyard Hockey', 'platforms': [{'id': 6, 'name': 'PC (Microsoft Windows)'}], 'release_dates': [{'id': 367840, 'y': 2002}], 'slug': 'backyard-hockey--2'}, {'id': 122753, 'age_ratings': [{'id': 72536, 'rating': 8}], 'category': 0, 'name': 'Backyard Hockey', 'slug': 'backyard-hockey--1'}, {'id': 49244, 'age_ratings': [{'id': 72537, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'name': 'Backyard Hockey', 'platforms': [{'id': 24, 'name': 'Game Boy Advance'}], 'release_dates': [{'id': 95795, 'y': 2003}], 'similar_games': [{'id': 4048, 'name': 'NHL Hitz Pro'}, {'id': 5071, 'name': 'NHL Slapshot'}, {'id': 5826, 'name': 'ESPN NHL 2K5'}, {'id': 8841, 'name': 'ESPN NHL Hockey'}, {'id': 27062, 'name': 'NHL Hockey'}, {'id': 44993, 'name': 'Backyard Soccer'}, {'id': 46638, 'name': 'Backyard Hockey 2005'}, {'id': 57656, 'name': 'Ice Hockey'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 116353, 'name': 'Real Football 2019'}], 'slug': 'backyard-hockey', 'summary': "Skate, shoot and score with the Backyard Kids and kid versions of the hottest NHL? pros! You can control all of the action in this hockey favorite. Build your own talented team, choose an awesome rink and zoom down the ice! With zany power-ups and that one-of-a-kind Backyard Sports excitement, Backyard Hockey provides fun, speedy, end-to-end action. Now that it's on the Game Boy Advance system, you can hit the game-winning slapshot anywhere", 'tags': [268435470, 536870956, 536871368, 536871745, 536872475, 536873064, 536873274, 536875257, 536875735, 536875868, 536875941, 536877938, 536881516]}, {'id': 46638, 'age_ratings': [{'id': 61857, 'rating': 8}], 'category': 0, 'genres': [{'id': 14, 'name': 'Sport'}], 'name': 'Backyard Hockey 2005', 'platforms': [{'id': 6, 'name': 'PC (Microsoft Windows)'}], 'release_dates': [{'id': 97961, 'y': 2004}], 'similar_games': [{'id': 3562, 'name': "NHL Blades of Steel '99"}, {'id': 72711, 'name': 'Backyard Soccer 2004'}, {'id': 109606, 'name': 'Pro Yakyuu Spirits 2019'}, {'id': 114286, 'name': 'Madden NFL 20'}, {'id': 114287, 'name': 'FIFA 20'}, {'id': 116349, 'name': 'Real Football 2014'}, {'id': 116350, 'name': 'Real Football 2015'}, {'id': 116351, 'name': 'Real Football 2017'}, {'id': 116352, 'name': 'Real Football 2018'}, {'id': 116353, 'name': 'Real Football 2019'}], 'slug': 'backyard-hockey-2005', 'summary': 'Backyard Hockey returns for 2005 with a new lineup of NHL kids and new 3d gameplay. This year you can draft from 30 backyard kids and 14 NHL Stars. You can also create custom players that improve with experience. All 30 NHL teams are included along with favorite backyard teams from earlier editions. \n \nThe game features three modes: Quick play, Season Play and Exhibition. The games can take place in nine different rinks including Sharkbelly Shores, Ice Castle Arcade and street hockey areas. As you progress you can unlock secret NHL players, rinks, bonus music etc. \n \nThe game keeps stats of players and teams throughout the season. Also a bonus Air Hockey Mini-Game is included.', 'tags': [268435470, 536871368, 536871745, 536875562, 536875735, 536884022]}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[196], line 6
#       4 search_type = 'search'
#       5 query = format_query(title, search_type=search_type)
# ----> 6 response = post_request(query, twitch_client_id, access_token)
#       7 result = validate_response(response, title, exact_matches_only=False)
#       9 if isinstance(result, dict):
#
# File ~\DataspellProjects\VGRecomendation\data_pull.py:139, in post_request(query, twitch_client_id, access_token, endpoint)
#     133 url = base_igdb_url + "/" + f"{endpoint}"
#     135 headers = {'headers': {'Client-ID': twitch_client_id,
#     136                        'Authorization': f"Bearer {access_token}"},
#     137            'data': query}
# --> 139 response = requests.post(url, **headers)
#     141 if response is None:
#     142     return None
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\AppData\Roaming\JetBrains\DataSpell2022.2\projects\workspace\venv\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
print(failed_chunks[0])
# Out:
# ('NBA', "Pro Yakyuu Greatest Nine '97", 'Dorabase DS: Dramatic Stadium', 'EVE: burst error', "Backyard NFL Football '09", 'Big League Sports', "Magician's Quest: Town of Magic", 'Momotarou Dentetsu 16', 'Robotech: The Macross Saga', 'Yu Yu Hakusho: Dark Tournament', 'Gekijouban Macross F: Itsuwarino Utahime - Hybrid Pack', 'World Poker Tour', 'GRID Autosport', 'Ghostbusters II', 'RealSports Baseball', 'Quake III: Revolution', 'Pac-Man World 3', 'Naruto: Clash of Ninja (JP sales)', 'NOëL: NOT DiGITAL', 'Transformer: Rise of the Dark Spark', 'Dragon Ball Z Hyper Dimension', 'Maximo vs Army of Zin', "The Fairly OddParents: Breakin' Da Rules", 'Namco Museum Megamix', 'Valkyria Chronicles III: Unrecorded Chronicles', "Cruis'n Exotica", "The King of Fighters '96", 'WRC: FIA World Rally Championship', 'Famicom Mini: Ganbare Goemon! Karakuri Douchuu', 'J-League Winning Eleven 10 + Europa League 06-07', 'Tales of Phantasia: Narikiri Dungeon X', 'JSRF: Jet Set Radio Future', 'The Last Airbender', 'StokEd', 'ESPN Winter X Games: Snowboarding 2002', 'I Spy: Castle', 'Shin Megami Tensei: Persona 3 (jp sales)', 'Barbie Fashion Show: An Eye for Style', 'Heisei Kyouiku linkai DS', 'SpongeBob SquarePants: Game Boy Advance Video Volume 3', 'BeyBlade VForce: Super Tournament Battle', 'Little Battlers eXperience: Baku Boost', 'Jikkyou Powerful Pro Yakyuu 2012', 'Attack on Titan (KOEI)', 'Beyblade G-Revolution', 'SD Gundam GNext', 'Backyard NFL Football 2006', 'Sloane to MacHale no Nazo no Monogatari', 'Dark Messiah of Might and Magic Elements', 'Just Dance 2: Extra Songs', 'International Superstar Soccer 2000', 'CandyLand / Chutes & Ladders / Memory', 'The Bible Game', "Drift King Shutokou Battle '94", 'PBR: Out of the Chute', 'The King of Fighters Collection: The Orochi Saga', 'Jikkyou Powerful Pro Yakyuu 10 Chou Ketteiban: 2003 Memorial', 'Samurai Spirits (CD)', 'Rocket Power: Zero Gravity Zone', 'Le Mans 24 Hours', 'Captain America: Super Soldier', 'Mobile Suit Gundam Side Story II: Aoi o Uketsugu Mono', 'Kurohyou 2: Ryu ga Gotoku Ashura Hen', 'Taiko no Tatsujin: Waku Waku Anime Matsuri', 'Ogre Battle Saga Episode Five: The March of the Black Queen', "Ni Hao, Kai-lan: New Year's Celebration", 'The Legend of Heroes VII: The Trail of Blue', 'CSI: Unsolved!', 'Roadsters 99', 'Magical Tetris Challenge', "Disney's Tarzan", 'San Francisco Rush 2049', 'Magical ZhuZhu Princess: Carriages & Castles', 'Total War: Shogun 2 - Fall of the Samurai', 'Pro Yaky? Spirits 2013', 'We Wish You A Merry Christmas', 'BioShock The Collection', 'Namco Museum Vol.4', 'Teenage Mutant Ninja Turtles 3: Mutant Nightmare', 'Pro Yaky? Spirits 2012', 'Puzzle & Dragons X: God Chapter / Dragon Chapter', "Sid Meier's Pirates!", 'Bust-A-Move 2 Arcade Edition', 'Tetris Worlds (Online Edition)', 'Go Play: Lumberjacks', 'Puzzle Challenge: Crosswords and More!', 'Backyard Hockey', 'The Fairly Odd Parents: Enter the Cleft', 'DS Kageyama Method: Dennou Hanpuku - Masu x Masu Hyaku Masu Keisan', 'Family Guy', 'Mega Man Legacy Collection', 'Big Mutha Truckers 2', 'The Great Escape', "Dexter's Lab Chess Challenge", 'Nostalgia', 'The Rise of the Argonauts', 'ESA Foundation Compilation', 'Dragon Ball Z: Idainaru Dragon Ball Densetsu', 'Ni Hao, Kai-lan: Super Game Day', 'Petz Pony: Beauty Pageant')

# %% [markdown]
# We now have 27 chunks of titles to retry querying with search_type = 'search'

# %%
game_library
# Out:
#           id  release_dates                             name       category  \
# 0       2181         2006.0                       Wii Sports      main_game
# 1        358         1987.0                Super Mario Bros.      main_game
# 2       2183         2008.0                   Mario Kart Wii      main_game
# 3       2182         2009.0                Wii Sports Resort      main_game
# 4       1076         2006.0            New Super Mario Bros.      main_game
# ...      ...            ...                              ...            ...
# 12916  63706         2001.0       Densha de GO! 3 Tsuukinhen      main_game
# 12917   5642         2009.0  Guilty Gear XX Accent Core Plus  expanded_game
# 12918  38477         2008.0      Higurashi Daybreak Portable           port
# 12919  49457         2006.0   WinX Club: Quest for the Codex      main_game
# 12920   5924         2011.0    Dead Rising 2: Off the Record  expanded_game
#
#                                   slug  \
# 0                           wii-sports
# 1                     super-mario-bros
# 2                       mario-kart-wii
# 3                    wii-sports-resort
# 4                 new-super-mario-bros
# ...                                ...
# 12916        densha-de-go-3-tsuukinhen
# 12917  guilty-gear-xx-accent-core-plus
# 12918      higurashi-daybreak-portable
# 12919    winx-club-quest-for-the-codex
# 12920     dead-rising-2-off-the-record
#
#                                                platforms  \
# 0                                                ['Wii']
# 1      ['Wii', 'Nintendo Entertainment System', 'Nint...
# 2                                                ['Wii']
# 3                                                ['Wii']
# 4                               ['Nintendo DS', 'Wii U']
# ...                                                  ...
# 12916                        ['PlayStation 2', 'Arcade']
# 12917  ['Wii', 'PlayStation 2', 'PlayStation 3', 'Xbo...
# 12918                           ['PlayStation Portable']
# 12919                               ['Game Boy Advance']
# 12920  ['PC (Microsoft Windows)', 'PlayStation 3', 'X...
#
#                                             genres  \
# 0                           ['Simulator', 'Sport']
# 1                        ['Platform', 'Adventure']
# 2                                       ['Racing']
# 3                                        ['Sport']
# 4                        ['Platform', 'Adventure']
# ...                                            ...
# 12916                                ['Simulator']
# 12917                                 ['Fighting']
# 12918                                 ['Fighting']
# 12919                                ['Adventure']
# 12920  ["Hack and slash/Beat 'em up", 'Adventure']
#
#                                                     tags  \
# 0      ['40', '268435469', '268435470', '536870932', ...
# 1      ['1', '268435464', '268435487', '536870928', '...
# 2      ['1', '27', '40', '268435466', '536870937', '5...
# 3      ['40', '268435470', '536870942', '536870970', ...
# 4      ['1', '268435464', '268435487', '536870928', '...
# ...                                                  ...
# 12916                                ['32', '268435469']
# 12917  ['17', '18', '268435460', '536870990', '536871...
# 12918                                 ['1', '268435460']
# 12919  ['1', '34', '268435487', '536875054', '5368752...
# 12920  ['1', '19', '27', '33', '38', '268435481', '26...
#
#                                              age_ratings     rating  \
# 0      ['E', 'Seven', 'CLASS_IND_L', 'CERO_B', 'USK_1...  74.803922
# 1      ['E', 'Three', 'CLASS_IND_L', 'CERO_A', 'USK_0...  83.948468
# 2      ['E', 'Three', 'CLASS_IND_L', 'CERO_A', 'ACB_G...  80.180221
# 3      ['E', 'Seven', 'CLASS_IND_L', 'CERO_B', 'USK_1...  78.657933
# 4      ['E', 'CLASS_IND_L', 'CERO_A', 'USK_0', 'ACB_P...  82.089739
# ...                                                  ...        ...
# 12916                                                NaN        NaN
# 12917                               ['GRAC_Twelve', 'M']  79.738110
# 12918                                         ['CERO_B']        NaN
# 12919                                              ['E']        NaN
# 12920  ['M', 'CERO_Z', 'GRAC_Eighteen', 'Eighteen', '...  71.261226
#
#        rating_count                                      similar_games  \
# 0               301  ['Tekken 3', 'Tekken 5', 'Journey', 'Wii Sport...
# 1              1041  ['Zelda II: The Adventure of Link', 'The Legen...
# 2               458  ['Wreckfest', 'Cocoto Kart Racer', 'Borderland...
# 3               137  ['Wii Sports', 'Wii Play', 'Wii Fit', 'Wii Fit...
# 4               287  ['Super Mario Bros.', 'The Legend of Zelda: Tw...
# ...             ...                                                ...
# 12916             0  ['Industry Giant', 'Sovereignty: Crown of King...
# 12917            18  ['The Legend of Heroes: Trails of Cold Steel',...
# 12918             0  ['Dragon Ball Z: Budokai Tenkaichi 3', 'One Pi...
# 12919             0  ['Cyberpunk 2077', "Don't Knock Twice", "Marve...
# 12920            35  ['Dead Rising 2', 'Watch Dogs', 'Spec Ops: The...
#
#                                                   themes  \
# 0                                              ['Party']
# 1                                             ['Action']
# 2                          ['Action', 'Comedy', 'Party']
# 3                                              ['Party']
# 4                                             ['Action']
# ...                                                  ...
# 12916                                    ['Non-fiction']
# 12917                     ['Fantasy', 'Science fiction']
# 12918                                         ['Action']
# 12919                          ['Action', 'Educational']
# 12920  ['Action', 'Horror', 'Comedy', 'Sandbox', 'Ope...
#
#                                                  summary  \
# 0      Bowl like a pro or go for that home run...\r\n...
# 1      A side scrolling 2D platformer and first entry...
# 2      Mario Kart Wii is a multiplayer-oriented racin...
# 3      Set off on a journey to a tropical island wher...
# 4      New Super Mario Bros. is a side-scrolling 2.5D...
# ...                                                  ...
# 12916  Densha de Go! 3 Tsuukin-hen (loosely translate...
# 12917  Λ Core Plus also features a new Story mode. Th...
# 12918  This game is an enhanced port of the doujin ga...
# 12919  Welcome to the magical world of Winx Club wher...
# 12920  The new "Off the Record" storyline means an al...
#
#                                       involved_companies
# 0      ['Nintendo', 'Nintendo EAD Software Developmen...
# 1            ['Nintendo', 'Nintendo R&D4', 'Playtronic']
# 2                           ['Nintendo', 'Nintendo EAD']
# 3      ['Nintendo', 'Nintendo EAD Software Developmen...
# 4       ['Nintendo EAD', 'Nintendo', 'Nintendo', 'iQue']
# ...                                                  ...
# 12916                 ['Taito', 'Taito GM R&D Sect. #2']
# 12917                ['Arc System Works', 'Aksys Games']
# 12918                             ['Cavia', 'Alchemist']
# 12919                                                NaN
# 12920  ['Capcom Game Studio Vancouver, Inc.', 'Capcom...
#
# [12921 rows x 15 columns]

# %%
def search_library(col_name: str, search_term: str):
    notna_library = game_library[game_library['name'].notna()]
    search_result = notna_library[notna_library[col_name].str.contains(search_term)]
    return pd.DataFrame(search_result)

# %%
search_library('name', 'Nancy Drew')
# Out:
#          id  release_dates                                               name  \
# 4579  47907         2008.0  Nancy Drew: The Mystery of the Clue Bender Soc...
# 5665  47916         2008.0                   Nancy Drew: The Hidden Staircase
# 6106   5050         2008.0         Nancy Drew: The White Wolf of Icicle Creek
#
#        category                                               slug  \
# 4579  main_game  nancy-drew-the-mystery-of-the-clue-bender-society
# 5665  main_game                    nancy-drew-the-hidden-staircase
# 6106  main_game          nancy-drew-the-white-wolf-of-icicle-creek
#
#                               platforms                            genres  \
# 4579                    ['Nintendo DS']                     ['Adventure']
# 5665                    ['Nintendo DS']           ['Puzzle', 'Adventure']
# 6106  ['Wii', 'PC (Microsoft Windows)']  ['Point-and-click', 'Adventure']
#
#                                                    tags age_ratings  \
# 4579  ['1', '43', '268435487', '536871127', '5368718...     ['E10']
# 5665  ['268435465', '268435487', '536871874', '53687...       ['E']
# 6106  ['268435458', '268435487', '536871127', '53687...       ['E']
#
#          rating  rating_count  \
# 4579        NaN             0
# 5665        NaN             0
# 6106  70.007982            10
#
#                                           similar_games  \
# 4579  ['Savage Lands', 'GreedFall', 'Blacksad: Under...
# 5665  ['Rusty Lake: Roots', "Don't Knock Twice", 'Qu...
# 6106  ['Nancy Drew: Legend of the Crystal Skull', 'M...
#
#                      themes  \
# 4579  ['Action', 'Mystery']
# 5665                    NaN
# 6106                    NaN
#
#                                                 summary  \
# 4579  The Clue Bender Society, a group consisting of...
# 5665  NANCY'S ON THE CASE! Family heirlooms are disa...
# 6106     Follow a Trail to Hidden Secrets and Sabotage!
#
#                                      involved_companies
# 4579  ['Majesco Entertainment', 'Gorilla Systems Cor...
# 5665                          ['Majesco Entertainment']
# 6106                        ['Her Interactive', 'Sega']
